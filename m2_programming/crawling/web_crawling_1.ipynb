# %% [markdown]
# #### HTML의 구조  및 태그
# - 구조
#  - \<!Doctype html> : HTML5 문서를 선언하는 구문
#  - \<html></html> : HTML 문서의 시작과 끝
#  - \<head></head> : CSS, JavaScript, meta, title 정보들을 설정
#  - \<body></body> : 실제 홈페이지 화면을 나타내는 부분
#
# - 요소 구조
#  - HTML 요소는 여러 속성들을 가질 수 있으며 속성들은 해당 요소에 대한 추가 정보를 제공
#  - 시작 태그\(< >)로 시작해서 종료 태그(</>)로 끝남
#  - 요소 안에 다른 요소를 작성할 수 있음
#  <img src = './dataset/html요소구조.jpg' STYLE = 'width:600px;'>

# %% [markdown]
# #### HTML 태그
# - p 태그를 이용하여 문단 작성
# - h 태그를 이용하여 폰트 크기 설정
# - ul(unordered list)과 ol(ordered list) 태그로 리스트 작성, 리스트 각각의 요소는 li(항목 나열) 태그로 표시
# - table 태그는 thead, tbody를 가질 수 있으며 표를 표현 : tr 행, th(가운데 정렬,굵은 글씨체),td 각 행의 컬럼
# - input 태그와 button 태그 : 데이터를 넣는 폼과 페이지 조작 버튼 생성
# - select # select 태그로 선택 리스트 생성
# - a 태그로 다른 페이지로 이동. 상대경로(내가 있는 경로부터의 경로), 절대경로(항상 같은 url)
# - img 태그로 이미지 포함 : src(이미지 붙임), alt(이미지 대체)
# - span 태그로 p태그 처럼 글을 추가. span 태그는 옆으로 나열. br 태그 사용하여 p 태그처럼 사용
# - div 태그는 화면 레이아웃을 잡는 역할 : 하위 태그들의 영역을 잡아줌

# %% [markdown]
# #### JavaScript
# - 웹 사이트의 기능을 넣어줌. script 태그를 이용하여 작성. head or body 하단에 위치
# - js를 이용하여 HTML 코드를 생성. 크롤러로 분석하기 가장 어려운 부분임
# - DOM(Document Object Model)이란 HTML을 시각적으로 쉽게 표현하기 위해 만든 객체로 크롤러 만들 때 중요
# - 데이터를 수집하기 위해 DOM을 이용해 데이터에 접근한 후 해당 데이터 수집
# - 웹 브라우저는 HTML 코드를 가져온 후 JavaScript를 실행시킨 결과를 보여줌
# - 소스 보기 페이지에 수집하고자 하는 요소가 없다면 네트워크 탭을 이용, 서버에서 데이터를 받아오는 지 확인
# - 그렇지 않은 경우 셀레니움을 사용하여 해결

# %% [markdown]
# #### CSS
# CSS로 웹 사이트를 꾸며주기 위해 해당 태그에 접근하는 방식을 크롤러에서도 사용.
# selector : CSS로 꾸미기 위해 특정 요소에 접근하는 것을 셀렉터라고 함.
# html 파일을 만들었다면 각각의 태그에 다르게 css 를 설정 할 것입니다. 이 때, 어느 요소에 스타일을 적용할지 알려주는 방식이 바로 css 선택자 입니다.
# 태그를 이용하여 접근하면 태그는 전부 CSS 효과가 적용
# class를 이용하면 원하는 요소만 CSS 효과 적용할 수 있고 원하는 요소만 수집할 수 있음.
# id는 class와 다르게 id값이 고유해야 함(id는 한페이지에 하나만 존재해야 함)
# 부모 태그와 자식 태그를 나열하여 복잡한 셀렉터를 생성
# CSS 선택자 이해
#
# https://ssungkang.tistory.com/entry/css-css-%EC%84%A0%ED%83%9D%EC%9E%90selector-%EC%9D%98-%EC%A2%85%EB%A5%98%EC%99%80-%EC%98%88%EC%8B%9C
# https://developer.mozilla.org/en-US/docs/Web/CSS/CSS_Selectors
# https://www.nextree.co.kr/p8468/
# 1
# css = """

# %% [markdown]
# http://www.tcpschool.com/javascript/js_dom_document

# %% [markdown]
# 파이썬을 활용한 데이터 가공
# - 문자열 자료형 (인덱싱) : 시퀀스 자료형으로 인덱스가 있고 인덱스 값으로 접근이 가능함
# - 파이썬에서 문자열을 쉽게 다룰 수 있도록 제공하는 내장함수
#     - find:해당문자가 없으면 -1 반환
#     - index:해당문자가 없으면 에러
#     - strip: 데이터 가공 초기 단계에 불필요한 공백을 지울 때 사용
#     - replcae: 특정 문자를 원하는 내용으로 변경
# - 정규표현식
#  - 특정한 규칙을 가진 문자열을 표현하기 위해 사용하는 형식
#  - 주로 문자열의 검색 및 치환에 활용
#  - re 모듈을 제공
#  - 규칙을 정의하기 위해 메타 문자를 활용

# %%
# 인덱싱
text = 'k-digital training 5기'
text1 = 'abc'
print(text[0])
print(text[-1])
print(text1[0])
print(text1.capitalize())
print(text1.upper())
# Out:
# k
# 기
# a
# Abc
# ABC

# %%
#'K-Digital Traning 5기'를 출력하세요
text1 = '  < k-digital traning 5기>   '
text2 =';'

# %%
#Q. < k-digital traning 5기>; 를 출력하세요
(text1.strip()+text2)
# Out:
# '< k-digital traning 5기>;'

# %%
#Q. < k-digital traning 5기>  ;를 출력하세요
(text1.lstrip()+text2)
# Out:
# '< k-digital traning 5기>   ;'

# %%
#Q.    < k-digital traning 5기> ; 를 출력하세요
text1.rstrip()+text2
# Out:
# '  < k-digital traning 5기>;'

# %%
text = '<title>k-digital training 5기</title>'

# %%
#Q. text를 아래와 같이 출력하세요
#<div> k-digital training 5기</title>
text.replace('title','div',1)
# Out:
# '<div>k-digital training 5기</title>'

# %%
#<div> k-digital training 5기</div>
text.replace('title','div')
# Out:
# '<div>k-digital training 5기</div>'

# %%
import re

data ='''
park 800980-1049118
kim 700905-1059119
'''

pat= re.compile('(\d{6}[-]\d{7)')

print(pat.sub('\g<1>-******',data))
# Out:
# re.compile('(\\d{6}[-]\\d{7)')
#
# park 800980-1049118
# kim 700905-1059119

# %%
.문자(\n)를 제외한 모든 문자와 매치
^ 첫번쨰 $ 마지막 * 0회이상 + 1회이상 ? 0또는1번 {} m,n범위
[] \n0-9 역슬레쉬 0-9 이런거 넣을 때 대괄호사용 \nw

# %%
text = ('111<head>안녕하세요</head>22')
#<head>안녕하세요</head>
import re
m=re.findall('.[a-z가-하]+',text)
m
# Out:
# ['<head', '>안녕하세요', '/head']

# %%
t = re.compile('[^0-9]+').search(text)
t.group()
# Out:
# '<head>안녕하세요</head>'

# %%
body = re.search(r'\D+',text)
body.group()
# Out:
# '<head>안녕하세요</head>'

# %%
han= re.search('[가-핳]+',text)
han.group()
# Out:
# '안녕하세요'

# %%
text='<head>안녕하세요..,<title>k-digital training 5기</title>반갑습니다...</head>'

# %%
# Q.<title>k-digital training 5기</title>를 출력하세요
s = re.search('<title>k-digital training 5기</title>',text)
s.group()
# Out:
# '<title>k-digital training 5기</title>'

# %%
sss =re.search('<title>.*</title>',text)
sss.group()
# Out:
# '<title>k-digital training 5기</title>'

# %%
# Q. k-digital training 5기 만 출력
ss =re.search('k-digital training 5기',text)
ss.group()
# Out:
# 'k-digital training 5기'

# %%
ssss= re.sub('<.+?>','',text)
ssss
# Out:
# '안녕하세요..,k-digital training 5기반갑습니다...'

# %%
requests 모듈
- pip install requests 명령어로 설치
- http는 요청과 응답으로 이루어져 있음
- 요청 응답 구조
    -GET: 정보를 가져오기 위해 요청
    -POST:새로운 정보를 보내기 위해 요청
    -PUT:수정할 정보를 보내기 위해 요청
    -DELETE:정보를 삭제하기 위해 요청
-응답
    -1XX: 요청을 받았고 작업 진행 중
    -2XX: 사용자의 요청이 성공적으로 수행됨
    -3XX: 요청은 완료되었으나 리다이렉션이 필요
    -4XX: 사용자의 요청이 잘못됨
    -5XX: 서보 오류가 발생함

# %%
# !pip install requests

# %%
import requests
url ='http://naver.com'
response =requests.get(url)
response.status_code
html_data =response.text
html_data
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네
# ...

# %%
html_data.find('네이버')
# Out:
# 365

# %%
html_data[365:368]
# Out:
# '네이버'

# %%
na =re.search('[가-핳]+',html_data)
na.group()
# Out:
# '네이버'

# %%
html_data.find('<meta property=')
print(html_data[390:500])
# Out:
#  만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/">

# %%
content0 = html_data.split('<meta property=')[0]
content1 = html_data.split('<meta property=')[1]
print(content0,'\n')
print(content1)
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>
#
# "og:title" content="네이버">

# %%
content = re.search('네이버+',content1)
content.group()
# Out:
# '네이버'

# %%
url = 'https://search.naver.com/search.naver'
params={'query':'AI'}  #검색값
response = requests.get(url,params=params)
response.status_code
response.text
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="AI : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'AI\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'AI\'의 네이버 통합검색 결과입니다."> <title>AI : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_220127.css"> <link rel="stylesheet" type="text/css" href="
# ...

# %%
url = 'https://comic.naver.com/webtoon/detail'
params ={'titleld':784255,'no':29,'weekday':'wed'}
response =requests.get(url,params=params)
response.text
# Out:
# '\r\n\r\n\r\n  \r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<!DOCTYPE html>\r\n<html lang="ko">\r\n<head>\r\n\t\r\n\t\t\r\n\t\t\r\n\t\t\r\n\t\t\r\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\r\n\t\t\r\n\t<meta http-equiv="Content-type" content="text/html; charset=UTF-8">\r\n\t<title>네이버 만화</title>\r\n\t\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n        <meta property="og:title" content="네이버 웹툰" >\r\n        <meta property="og:image" content="https://ssl.pstatic.net/static/comic/images/og_tag_v2.png" >\r\n        <meta property="og:description" content="매일매일 새로운 재미, 네이버 웹툰.">\r\n    \r\n\r\n\r\n<meta property="og:url" content="https://comic.naver.com/main" >\r\n<meta property="og:type" content="article" >\r\n<meta property="og:article:author" content="네이버 웹툰" >\r\n<meta property="og:article:author:url" content="https://comic.naver.com" >\r\n\r\n\t<link rel
# ...

# %%
# Q.네이버 사이트에서 공지사항 출력
url='https://naver.com'
params ={'class':'notice_box'}
response=requests.get(url,params=params)
nav = response.text
nav
import re
p =re.search('공지사항',nav)
p.group()
# Out:
# '공지사항'

# %%
url = 'https://naver.com'
res = requests.get(url)
res.status_code
r = res.text

# 인덱싱
rr = r.find('공지사항')
display(rr,
        r[rr:(rr+4)])
# Out:
# 157609
# '공지사항'

# %% [markdown]
# #### Beautiful Soup 모듈
# - 홈페이지 내 데이터를 쉽게 추출할 수 있게 해주는 파이썬 외부 라이브러리
# - 웹 문서 내 수많은 HTML 태그들을 parser를 활용해 사용하기 편한 파이썬 객체로 만들어 제공
# - 웹 문서 구조를 알고 있다면 편하게 데이터를 뽑아 활용할 수 있음
# - BS는 HTML 문서를 태그를 기반으로 구조화하여 태그로 원하는 데이터를 찾아가는 형식
# - find(): HTMl의 해당 태그에 대한 첫번째 정보를 가져옴
#   -find(속성='값'): HTML 해당 속성과 일치하는 값에 대한 첫번째 정보를 가져옴
# - find_all(),findAll
#   -HTML의 해당 태그에 대한 모든 정보를 리스트 형식으로 가져옴, limit옵션으로 개수 지정 가능
#   -CSS 속성으로 필터링(class_로 클래스를 직접 사용 혹은 attrs에서 속성=값으로 필터링)
# - select_one(),select()
#     -CSS 선택자를 활용하여 원하는 정보를 가져옴(태그를 검색하는 find,find_all과 비슷함)
#     -class는 ., id는 #로 표시

# %%
# !pip install beautifulsoup4

# %%
html_doc="""
<html lang='en'>
<head><title>crawl</title></head>
<body>
<p class='a' align='center'> text1<p>
<p class='b' align='center'> text2<p>
<p class='c' align='center'> text3<p>
<div><img height='200' src='/source' width='300'></div>
</body>
</html>
"""
from bs4 import BeautifulSoup
soup =BeautifulSoup(html_doc,'html.parser')
print(soup.prettify())
# Out:
# <html lang="en">
#  <head>
#   <title>
#    crawl
#   </title>
#  </head>
#  <body>
#   <p align="center" class="a">
#    text1
#    <p>
#     <p align="center" class="b">
#      text2
#      <p>
#       <p align="center" class="c">
#        text3
#        <p>
#         <div>
#          <img height="200" src="/source" width="300"/>
#         </div>
#        </p>
#       </p>
#      </p>
#     </p>
#    </p>
#   </p>
#  </body>
# </html>

# %%
url ='http://naver.com'
req = requests.get(url)
html = req.text
html.find('blind')
html[9800:10000]
# Out:
# 'ver.com/banner/details/mousegesture?=main&wpid=RydDy7"\ndata-clk="dropbanner1b"\n></a\n><i class="_1KncATpM _1yl_Ow6o"><span class="blind">NAVER whale</span></i\n><img\nsrc="https://static-whale.pstatic.ne'

# %%
soup = BeautifulSoup(html,'html.parser')
result = soup.find(class_='blind')
result.text
# Out:
# 'NAVER whale'

# %%
#[과제] 네이버 홈페이지에 있는[ '메일','카페','블로그','지식인','쇼핑']을 출력하세요
url='https://www.naver.com/'
req = requests.get(url)
html = req.text
soup =BeautifulSoup(html,'html.parser')
soup.find('ul',attrs={'class':'list_nav type_fix'}).text
# Out:
# '\n\n메일\n\n카페\n블로그\n지식iN\n쇼핑\n쇼핑LIVE\nPay\n\nTV\n\n'

# %%
url = 'https://naver.com'
html = requests.get(url).text
soup = BeautifulSoup(html, 'html.parser')

re.search('메일', html)
print(html[25800:26200], '\n')
a = soup.select('div.group_nav')
b = soup.find_all('a', class_ = ['nav'])[0:5]

c = [i.text for i in b]
print(c)
# Out:
# div class="group_nav">
# <ul class="list_nav type_fix">
# <li class="nav_item">
# <a href="https://mail.naver.com/" class="nav" data-clk="svc.mail"><i class="ico_mail"></i>메일</a>
# </li>
# <li class="nav_item"><a href="https://section.cafe.naver.com/" class="nav" data-clk="svc.cafe">카페</a></li>
# <li class="nav_item"><a href="https://section.blog.naver.com/" class="nav" data-clk="svc.blog">블로그</a></li>
# <li cl
#
# ['메일', '카페', '블로그', '지식iN', '쇼핑']

# %%
url ='http://naver.com'
req = requests.get(url)
html = req.text
soup =BeautifulSoup(html,'html.parser')
tag= soup.find('li',attrs = {'class':'nav'})
for tag in soup(class_='nav'):
    print(tag.text[:6])
# Out:
# 메일
# 카페
# 블로그
# 지식iN
# 쇼핑
# 쇼핑LIVE
# Pay
# TV
# 사전
# 뉴스
# 증권
# 부동산
# 지도
# VIBE
# 책
# 웹툰

# %%
html = """
<html><body>
  <h1 id ='title'>스크레이핑이란?</h1>
  <p id ='body'>웹 페이지를 분석하는 것</p>
  <p>원하는 부분을 추출하는 것</p>
</body></html>
"""
soup =BeautifulSoup(html,'html.parser')
body = soup.find(id='body')
title=soup.find(id='title')
body.text
title.string
# Out:
# '스크레이핑이란?'

# %%
h1 =soup.html.body.h1.string
h1
# Out:
# '스크레이핑이란?'

# %%
p1 =soup.html.body.p
p1
# Out:
# <p id="body">웹 페이지를 분석하는 것</p>

# %%
#p공백쪽도 있다고 감안해야돼서 
p2 =p1.next_sibling.next_sibling
p2
# Out:
# <p>원하는 부분을 추출하는 것</p>

# %%
#find_all()
soup= BeautifulSoup(html,'html.parser')
texts =soup.find_all('p')
for text in texts:
    print(text.text)
# Out:
# ON/OFF 설정은해당기기(브라우저)에 저장됩니다.
# 동일한 시간대/연령/남녀별 사용자 그룹의관심사에 맞춰 자동완성을 제공합니다.
# 해당 언론사 사정으로 접근이 제한됩니다.
# 을(를)구독해지 하시겠습니까?
# 구독한 언론사에 추가되었습니다.
# 해당 언론사 사정으로 접근이 제한됩니다.
# 을(를)구독해지 하시겠습니까?
# 구독한 언론사에 추가되었습니다.
# 해당 언론사 사정으로 접근이 일시 제한됩니다.
# 을(를)구독해지 하시겠습니까?
# 해당 언론사 사정으로 접근이 제한됩니다.
# 을(를)구독해지 하시겠습니까?
# 언론사 구독 설정에서 관심있는 언론사를 구독하시면언론사가 직접 편집한 뉴스들을 네이버 홈에서 바로 보실 수 있습니다.
#
# Connect with people

# %%
html = """
<html><body>
  <ul>
    <li><a href="http://www.naver.com">naver</a></li>
    <li><a href="http://www.daum.net">daum</a></li>
  </ul>
</body></html>
"""
soup =BeautifulSoup(html,'html.parser')
links=soup.find_all('a')

# %%
for a in links:
    print(a.text,'>',a.get('href'))
# Out:
# naver > http://www.naver.com
# daum > http://www.daum.net

# %%
import urllib.request as req
url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
res =req.urlopen(url)
soup = BeautifulSoup(res,'html.parser')
title =soup.find('title').string
title
# Out:
# '기상청 육상 중기예보'

# %%
url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
res= requests.get(url).text
soup = BeautifulSoup(res,'html.parser')
title= soup.find('wf').string
" ".join(re.findall('[^ a-zA-Z0-9]?[0-9가-힣]+[^A-Z0-9]?',title))
# Out:
# '(강수) 12일( 토) 오후  제주도에  비가  시작되어  13일( 일) 남부지방으로  확대되겠으며, 13일( 일) ~14일( 월) 강원영동에는  비  또는  눈이  오겠습니다. (기온) 이번  예보기간  아침  기온은  -9~ 6도, 낮  기온은  1~ 13도로  어제( 8일, 아침최저기온  -10~ 0도, 낮최고기온  5~ 9도) 보다  높겠습니다. (해상) 13( 일) ~14일( 월) 동해상과  남해동부해상, 제주도해상에서는  물결이  2. 0~ 4. 0m 로  매우  높게  일겠습니다. (주말전망) 12일( 토) 은  구름많겠으나, 제주도에는  비가  오겠으며, 13일( 일) 은  대체로  흐리고  전라권과  경상권, 제주도에  비가, 강원영동에는  비  또는  눈이  오겠습니다. 아침  기온은  -4~ 6도, 낮  기온은  6~ 13도가  되겠습니다. 12일( 토) ~14일( 월) 강수는  남쪽을  지나는  저기압의  위치와  이동속도에  따라  변동성이  있겠고, 13일( 일) ~14일( 월) 강원영동에는  많은  강수량이  예상되나  기온의  변화에  따라  강수형태( 비  또는  눈) 가  달라질  수  있으니, 앞으로  발표되는  기상정보를  참고하기  바랍니다.'

# %%
soup = BeautifulSoup(res ,'html.parser')
title = soup.find_all('wf')
len_text = title[0].text.split('<br />')
for i in len_text:
    k = re.search('[^○]+',i)
    print(k.group())
# Out:
#  (강수) 12일(토) 오후 제주도에 비가 시작되어 13일(일) 남부지방으로 확대되겠으며, 13일(일)~14일(월) 강원영동에는 비 또는 눈이 오겠습니다.
#  (기온) 이번 예보기간 아침 기온은 -9~6도, 낮 기온은 1~13도로 어제(8일, 아침최저기온 -10~0도, 낮최고기온 5~9도)보다 높겠습니다.
#  (해상) 13(일)~14일(월) 동해상과 남해동부해상, 제주도해상에서는 물결이 2.0~4.0m로 매우 높게 일겠습니다.
#  (주말전망) 12일(토)은 구름많겠으나, 제주도에는 비가 오겠으며, 13일(일)은 대체로 흐리고 전라권과 경상권, 제주도에 비가, 강원영동에는 비 또는 눈이 오겠습니다.
#               아침 기온은 -4~6도, 낮 기온은 6~13도가 되겠습니다.
# * 12일(토)~14일(월) 강수는 남쪽을 지나는 저기압의 위치와 이동속도에 따라 변동성이 있겠고, 13일(일)~14일(월) 강원영동에는 많은 강수량이 예상되나 기온의 변화에
#   따라 강수형태(비 또는 눈)가 달라질 수 있으니, 앞으로 발표되는 기상정보를 참고하기 바랍니다.

# %%
#[과제] wf 태그는 모두 출력 
url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
res= requests.get(url).text
soup = BeautifulSoup(res,'html.parser')
all =soup.find_all('wf')
all
# Out:
# [<wf><![CDATA[○ (강수) 12일(토) 오후 제주도에 비가 시작되어 13일(일) 남부지방으로 확대되겠으며, 13일(일)~14일(월) 강원영동에는 비 또는 눈이 오겠습니다. <br />○ (기온) 이번 예보기간 아침 기온은 -9~6도, 낮 기온은 1~13도로 어제(8일, 아침최저기온 -10~0도, 낮최고기온 5~9도)보다 높겠습니다.<br />○ (해상) 13(일)~14일(월) 동해상과 남해동부해상, 제주도해상에서는 물결이 2.0~4.0m로 매우 높게 일겠습니다.<br />○ (주말전망) 12일(토)은 구름많겠으나, 제주도에는 비가 오겠으며, 13일(일)은 대체로 흐리고 전라권과 경상권, 제주도에 비가, 강원영동에는 비 또는 눈이 오겠습니다. <br />              아침 기온은 -4~6도, 낮 기온은 6~13도가 되겠습니다.<br />* 12일(토)~14일(월) 강수는 남쪽을 지나는 저기압의 위치와 이동속도에 따라 변동성이 있겠고, 13일(일)~14일(월) 강원영동에는 많은 강수량이 예상되나 기온의 변화에 <br />  따라 강수형태(비 또는 눈)가 달라질 수 있으니, 앞으로 발표되는 기상정보를 참고하기 바랍니다.]]></wf>,
#  <wf>맑음</wf>,
#  <wf>구름많음</wf>,
#  <wf>흐림</wf>,
#  <wf>흐림</wf>,
#  <wf>구름많음</wf>,
#  <wf>흐림</wf>,
#  <wf>구름많음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>구름많음</wf>,
#  <wf>구름많음</wf>,
#  <wf>맑음</wf>,
#  <wf>구름많음</wf>,
#  <wf>흐림</wf>,
#  <wf>흐림</wf>,
#  <wf>구름많음</wf>,
#  <wf>흐림</wf>,
#  <wf>구름많음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
# ...

# %%
url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
res= requests.get(url).text
soup = BeautifulSoup(res,'html.parser')
find= soup.find('location wl_ver="3"')
find

# %%
url='https://naver.com'
text = requests.get(url).text
text
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네
# ...

# %%
import urllib
url ='https://naver.com'
response =urllib.request.urlopen(url)
byte_data =response.read()
html =byte_data.decode('utf-8') #디코딩함
soup =BeautifulSoup(html,'html.parser')
print(soup.find('a'))
print(soup.find(class_='blind'))
# Out:
# <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a>
# <span class="blind">NAVER whale</span>

# %%
soup.find_all('a',limit=2)[1]
# Out:
# <a href="#themecast"><span>주제별캐스트 바로가기</span></a>

# %%
soup.find_all('span',class_='blind')[0:3]
# Out:
# [<span class="blind">NAVER whale</span>,
#  <span class="blind">네이버</span>,
#  <span class="blind">쥬니어네이버</span>]

# %%
soup.find('a',class_='logo_naver').text
# Out:
# '네이버'

# %%
soup.find_all(string='네이버')
# Out:
# ['네이버']

# %%
print(soup.find_all(string=re.compile('네이버')))
# Out:
# ['네이버', '네이버를 시작페이지로', '쥬니어네이버', '언론사가 직접 편집한 뉴스들을 네이버 홈에서 바로 보실 수 있습니다.', '네이버스포츠', '[기획전] 2022년 신상부터 스테디셀러 상품 네이버 단독 특가!', '네이버스포츠', '네이버스포츠', '네이버스포츠', '네이버스포츠', '네이버스포츠', '네이버스포츠', '네이버스포츠', '네이버스포츠', '네이버스포츠', '네이버스포츠', '네이버스포츠', '크보연구소_네이버스포츠', '네이버 개발자 센터', '네이버 D2', '네이버 D2SF', '네이버 랩스', '네이버 정책 및 약관', '네이버 정책']

# %%
req = requests.get('http://movie.naver.com')
html = req.text
soup =BeautifulSoup(html,'html.parser')
text=soup.find('span',attrs={'class':'blind'})
print(text)
print(text.get_text())
print(text.get('class'))
# Out:
# <span class="blind">영화검색 영역</span>
# 영화검색 영역
# ['blind']

# %%
html = """
<html><body>
<div id="meigen">
  <h1>위키북스 도서</h1>
  <ul class="items">
    <li>유니티 게임 이펙트 입문</li>
    <li>스위프트로 시작하는 아이폰 앱 개발 교과서</li>
    <li>모던 웹사이트 디자인의 정석</li>
  </ul>
</div>
</body></html>
"""
soup = BeautifulSoup(html,'html.parser')
h1 = soup.select_one('div#meigen> h1').text
h1
# Out:
# '위키북스 도서'

# %%
li = soup.select('div#meigen>ul>li')
for i in li:
    print(i.string)
# Out:
# 유니티 게임 이펙트 입문
# 스위프트로 시작하는 아이폰 앱 개발 교과서
# 모던 웹사이트 디자인의 정석

# %%
# Q.네이버 환율 가져오기
url='https://finance.naver.com/marketindex/'
req = requests.get(url)
html=req.text
soup=BeautifulSoup(html,'html.parser')
text=soup.find_all('span',attrs={'class':'value'})
for t in text:
    print(t.string)
# Out:
# 1,195.40
# 1,034.04
# 1,365.09
# 187.84
# 115.4700
# 1.1430
# 1.3556
# 95.4900
# 89.66
# 1698.29
# 1835.2
# 70397.0

# %%
# Q.네이버 환율 가져오기
url='https://finance.naver.com/marketindex/'
req = requests.get(url)
html=req.text
soup=BeautifulSoup(html,'html.parser')
text=soup.find('span',attrs={'class':'value'})
for t in text:
    print(t.string)
# Out:
# 1,195.00

# %%
a = soup.select('div.group_nav')
b = soup.find_all('a', class_ = ['nav'])[0:5]

c = [i.text for i in b]
print(c)
# Out:
# ['메일', '카페', '블로그', '지식iN', '쇼핑']

# %%
c =soup.find('a',attrs={'class':'head usd'})
c.text
# Out:
# '\n미국 USD\n\n1,197.50\n원\n 1.00\n하락\n\n'

# %%
#[과제] 네이버 영화 랭킹 가져와서 첫번째 영화제목을 출력하세요
url= 'https://movie.naver.com/movie/sdb/rank/rmovie.naver'

req= requests.get(url)
html=req.text
soup= BeautifulSoup(html,'html.parser')
rank = soup.select_one("#old_content > table > tbody > tr:nth-child(2) > td.title > div > a") #selector요소
print(rank.text)
# Out:
# 해적: 도깨비 깃발

# %%
one =soup.find('div',attrs={'class':'tit3'})
one.text
# Out:
# '\n해적: 도깨비 깃발\n'

# %%
#[과제] 네이버 영화 랭킹 가져와서 전체 영화제목을 출력
url= 'https://movie.naver.com/movie/sdb/rank/rmovie.naver'

req= requests.get(url)
html=req.text
soup= BeautifulSoup(html,'html.parser')
names= soup.find_all('div',attrs={'class':'tit3'})
for n in names:
    print(n.text)
# Out:
# 해적: 도깨비 깃발
#
#
# 킹메이커
#
#
# 특송
#
#
# 스파이더맨: 노 웨이 홈
#
#
# 나일 강의 죽음
#
#
# 하우스 오브 구찌
#
#
# 씽2게더
#
#
# 경관의 피
#
#
# 355
#
#
# 어나더 라운드
#
#
# 언차티드
#
#
# 극장판 안녕 자두야: 제주도의 비밀
#
#
# 듄
#
#
# 드라이브 마이 카
#
#
# 미싱타는 여자들
#
#
# 킹스맨: 퍼스트 에이전트
#
#
# 셰터드
#
#
# 나의 촛불
#
#
# 인민을 위해 복무하라
#
#
# 수퍼모델
#
#
# 만년이 지나도 변하지 않는 게 있어
#
#
# 짬뽕비권
#
#
# 나이트메어 앨리
#
#
# 트로트는 인생이다
#
#
# 창극 변강쇠 점 찍고 옹녀
#
#
# 강릉
#
#
# 더 배트맨
#
#
# 인질
#
#
# 장민호 드라마 최종회
#
#
# 인어가 잠든 집
#
#
# 효자
#
#
# 삼진그룹 영어토익반
#
#
# 캐시트럭
#
#
# 블랙머니
#
#
# 극장판 주술회전 0
#
#
# 레지던트 이블: 라쿤시티
#
#
# 프랑스
#
#
# 굿 보스
#
#
# 안테벨룸
#
#
# 코로나
#
#
# 웨스트 사이드 스토리
#
#
# 가슴이 떨리는 건 너 때문
#
#
# 문폴

# %%
#[과제] 기상청 육상 정보에서 강원도 지역번호 105이다. 강원도의 날씨예보를 출력하세요
url = 'https://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=105'
req= requests.get(url)
html =req.text
soup= BeautifulSoup(html,'html.parser')
k = soup.find('wf').string
"".join(re.findall('[^ a-zA-Z0-9]?[0-9가-힣]+[^A-Z0-9]?',k))
# Out:
# '(강수)13일(일)~14일(월)강원영동에 비 또는 눈이 내리겠습니다.(기온)12일(토)~15일(화)아침 기온은 -7~2도,낮 기온은 -2~10도로 어제(8일,아침최저기온 -13~-2도,낮최고기온 2~7도)보다 조금 높겠고,16일(수)~19일(토)아침 기온은 -15~-1도,낮 기온은 -4~7도로 어제와 비슷하거나 조금 낮겠습니다.(해상)동해중부해상의 물결은 12일(토)까지 1.0~2.0m로 일다가 13일(일)오후~14일(월)오전에는 2.0~4.0m로 매우 높게 일겠습니다.(주말전망)12일(토)~13일(일)은 대체로 흐리겠고,13일(일)은 강원영동에 비 또는 눈이 내리겠습니다.아침 기온은 -7~2도,낮 기온은 1~10도가 되겠습니다.13일(일)~14일(월)강수는 남쪽을 지나는 저기압의 위치와 이동속도에 따라 변동성이 있겠고,강원영동에는 많은 강수량이 예상되나,기온의 변화에 따라 강수형태(비 또는 눈)가 달라질 수 있으니,앞으로 발표되는 기상정보를 참고하기 바랍니다.'

# %%
params={'query':'AI'}  #검색값
response = requests.get(url,params=params)
response.status_code

# %%
import re 
from bs4 import BeautifulSoup
import urllib.request
import urllib.parse
api ='https://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp'
values={
    'stnld':'109'
}
params= urllib.parse.urlencode(values)
url =api +'?'+params
print('url',url)

res=urllib.request.urlopen(url)
soup= BeautifulSoup(res,'html.parser')
wf =soup.find('wf').string
text =''.join(re.findall('[^ a-zA-Z0-9]?[0-9가-힣]+[^A-Z0-9]?',wf))
text
# Out:
# url https://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnld=109
# '(강수)13일(일)남부지방과 제주도에는 흐리고 비가 오겠으며,13일(일)~14일(월)강원영동에는 비 또는 눈이 오겠습니다.(기온)이번 예보기간 아침 기온은 -11~7도로 어제(9일,아침최저기온 -11~2도)와 비슷하거나 조금 높겠고,낮 기온은 1~11도로 어제(9일,낮최고기온 5~12도)보다 낮겠습니다.(해상)13일(일)~14일(월)동해상과 남해동부해상,제주도해상에서는 물결이 2.0~4.0m로 매우 높게 일겠습니다.(주말전망)12일(토)은 전국이 가끔 구름많겠으며,13일(일)은 전국이 대체로 흐리고 남부지방과 제주도에 비가,강원영동에는 비 또는 눈이 오겠습니다.아침 기온은 -6~7도,낮 기온은 6~14도가 되겠습니다.13일(일)~14일(월)강수는 남쪽을 지나는 저기압의 위치와 이동속도에 따라 변동성이 있겠고,강원영동에는 많은 강수량이 예상되나 기온의 변화에 따라 강수형태(비 또는 눈)가 달라질 수 있으니,앞으로 발표되는 기상정보를 참고하기 바랍니다.'

# %%
#[도전과제] 관심 내용에 대하여 웹에서 가져와서 정규표현식,BS를 이용하여 데이터 출력하세요

# %%
import pickle
f = open('시가총액.csv', 'wb')
data
pickle.dump(data,f)
f.close()

# %%
url='https://finance.naver.com/sise/lastsearch2.naver'
req= requests.get(url)
html =req.text
soup= BeautifulSoup(html,'html.parser')
filename = '시가총액 1-200.csv'
f = open('filename', 'w',encoding='utf-8-sig',newline='')

# %%
menu=soup.find('tr',attrs={'class':'type1'})
print(menu.get_text())
# Out:
# 순위
# 종목명
# 검색비율
# 현재가
# 전일비
# 등락률
# 거래량
# 시가
# 고가
# 저가
# PER
# ROE
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-687-34aeb9470d6b> in <module>
#       1 menu=soup.find('tr',attrs={'class':'type1'})
#       2 print(menu.get_text())
# ----> 3 f.write(menu)
#
# TypeError: write() argument must be str, not Tag

# %%
url= 'https://movie.naver.com/movie/bi/mi/point.naver?code=191547'

req= requests.get(url)
html=req.text
soup= BeautifulSoup(html,'html.parser')
review = soup.find_all('div',attrs={'class':'star_score'})
for r in review:
    rate =r.find('em')
    print(rate)
# Out:
# <em class="num8">8</em>
# <em class="num8">8</em>
# None
# None
# <em class="num8">8</em>
# <em class="num8">8</em>
# None
# None
# <em class="num8">8</em>
# <em class="num8">8</em>
# <em class="num8">8</em>

# %%
#첫 페이지 영화리뷰 내용 크롤링
revu =soup.find_all('td',attrs={'class':'title'})
for r in revu:
    print(r.text)
# Out:
# 나일 강의 죽음
#
# 별점 - 총 10점 중8
#
# 옛스럽다.. 나일강은 멋있다
#
#
#
#
#
#
# 				신고
#
#
# 나일 강의 죽음
#
# 별점 - 총 10점 중9
#
# 애거시 크리스티 원작이라 추리 스토리가 탄탄하네요 전반부 볼거리까지
#
#
#
#
#
#
# 				신고
#
#
# 킹스맨: 퍼스트 에이전트
#
# 별점 - 총 10점 중10
#
# 리얼 이후로 최고의 영화!
#
#
#
#
#
#
# 				신고
#
#
# 이터널스
#
# 별점 - 총 10점 중1
#
# 감동0  액션0 그냥 보지말고 딴영화보세요
#
#
#
#
#
#
# 				신고
#
#
# 킹메이커
#
# 별점 - 총 10점 중6
#
# 저도 신입 감독을 준비 하는 사람으로 말씀 드리면 한국 영화와 외국영화 차이점 외국영화 첨에 너무 지루함 끝이 반전 클라이스 죽임 한국영화 초반에 이야 너무 흥미 진진해 마지막 뭐야 왜 이따구로 만드는 거야 잠온다 잠와 나가자 이정도 그리고 왜 주인공은 안죽지 반전도 없고 감독이 문제야 배우가 문제야 이럼 제 댓글을 꼭 보세요 코로나 때문에 관객에 없는게 아닙니다 영화가 재미있으면 시간내서도 봅니다 화이팅하세요 외국영화는 처럼 영화는 만들어야죠 잔인하거 나쁜거만 모방하지말구요 마지막이 반전과 스릴러 그리고 단역이나 조연을 살려주세요 주연만 사는 영화는 재미 없습니다 조연인데 주연처럼 돋보이는 영화를 만들어죠 왜냐 관객은 주연에만 관심 이자나요  화이팅 하세요  신입감독을 준비하면서 코로나때문에 관객이 없는건 아니라고 생각해서 몇자 적어봅니다
#
#
#
#
#
#
# 				신고
#
#
# 나일 강의 죽음
#
# 별점 - 총 10점 중9
#
# 아름다웠던 나일강의 풍경과 탁 트인 시야.카메라 기법이 아주 좋았다.흥미진진했던 1970년대 추리물도 재미짐
#
#
#
#
#
#
# 				신고
#
#
# 나일 강의 죽음
#
# 별점 - 총 10점 중1
#
# 예교편이 누가 범인인걸 다 알려주네 ㅋㅋㅋ그래도 보실래요? ㅋㅋㅋ
#
#
#
#
#
# ...

# %%
url='https://movie.naver.com/movie/point/af/list.naver?st=mcode&sword=191547&target=after'
req= requests.get(url)
html=req.text
soup= BeautifulSoup(html,'html.parser')
nali =soup.find('span',attrs={'class':'st_off'})
for n in nali:
    nn=n.find('em').get_text()
    print(nn)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-385-70d26863c664> in <module>
#       5 nali =soup.find('span',attrs={'class':'st_off'})
#       6 for n in nali:
# ----> 7     nn=n.find('em').get_text()
#       8     print(nn)
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
cartoons = soup.find_all('div',attrs= {'class':'rating_type'})
for cartoon in cartoons:
    rate = cartoon.find('strong').get_text()
    print(rate)
    total_rates += float(rate)
print(total_rates)
print(total_rates/len(cartoons))
print(cartoons)
# Out:
# 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-292-c055c638e489> in <module>
#       5     total_rates += float(rate)
#       6 print(total_rates)
# ----> 7 print(total_rates/len(cartoons))
#       8 print(cartoons)
#
# ZeroDivisionError: division by zero

# %%
url= 'https://movie.naver.com/movie/bi/mi/review.naver?code=191547&page=1'
req= requests.get(url)
html=req.text
soup= BeautifulSoup(html,'html.parser')
score =soup.find_all('div',attrs={'class':'star_score'})
total_rates=0
for s in score():
    rate= s.find('em').span.text
    print(rate)
    total_rates += float(rate)

print(total_rates)
print(total_rates/len(score))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-3d8db2a8205a> in <module>
#       5 score =soup.find_all('div',attrs={'class':'star_score'})
#       6 total_rates=0
# ----> 7 for s in score():
#       8     rate= s.find('em').span.text
#       9     print(rate)
#
# TypeError: 'ResultSet' object is not callable

# %%
import requests
from bs4 import BeautifulSoup

url='https://movie.daum.net/moviedb/grade?movieId=117471'
req = requests.get(url)
html=req.text
soup=BeautifulSoup(html,'html.parser')

score = soup.select("#comment598200597 > div > div.ratings.rating_10")
for s in score:
    print(s.text)

# %%
import requests
from bs4 import BeautifulSoup

url='https://movie.daum.net/moviedb/grade?movieId=117471'
req = requests.get(url)
html=req.text
soup=BeautifulSoup(html,'html.parser')
rank = soup.find_all('div',attrs={'class':'ratings rating_10'})
for r in rank:
    print(r)

# %%
url='https://movie.naver.com/movie/bi/mi/point.naver?code=191547'
req=requests.get(url)
html=req.text
soup=BeautifulSoup(html,'lxml')
score_lis=[]
scores=soup.find_all('div','star_score')
for score in scores:
    score_lis.append(score.get_text())
print(score_lis)
# Out:
# ['\n관람객 평점 8.60점8.60\n', '\n9.03\n', '\n0점\n등록\n', '\n\n', '\n관람객 평점 8.60점8.60\n', '\n9.03\n', '\n0점\n등록\n', '\n\n', '\n\n9.03\n', '\n\n8.60\n', '\n별점 - 총 10점 중9.03\n']

# %%
#한 페이지 내 리뷰내용 추출
url='https://movie.naver.com/movie/bi/mi/review.naver?code=191547'
req=requests.get(url)
html=req.text
soup=BeautifulSoup(html,'lxml')
ul= soup.find('ul',attrs={'class':'rvw_list_area'})
lis= ul.find_all('li')
for li in lis:
    print(li.get_text())
# Out:
# 아미 해머의 키가 196cm란 지식 없이 이 사진을 보면 갤가돗의 키가 평범할거라 착각할 수도
# kong**** 2020.08.22추천 1
# 10월 23일 북미 개봉 예정 영화 <나일 강의 죽음(Death on  the Nile)>에서 사진 왼쪽 아미 해머의키가 무려 196cm이기에 178cm의 갤 가돗보다확실히 더 커 보인다.만약 두 배우에 대한 사전 지식이 전혀 없는 사람이위 사진을 처음...
#
#
# 갤가돗 신작 영화 <나일 강의 죽음> 트레일러 (북미 10월 23일 개봉 예정)
# kong**** 2020.08.20추천 0
# 갤가돗 신작 <나일 강의 죽음(Death on the Nile)>예고편 동영상북미 10월 23일 개봉 예정 https://youtu.be/9yn5gRiKnzQ동영상Gal Gadot - Death on the Nile - Trailer #01First trailer of the Movie "Death on the Nile&qu...
#
#
# 케너스 브래너 감독의 영화 <나일 강의 죽음> 애거서 크리스티 추리 소설을 소재로 만들다.
# trja**** 2020.09.22추천 0
# 추리 소설하면 떠오르는 유일한 인물인 애거서 크리스티라고 할 수 있을 정도로 그의 작품은 추리 소설로 독보적이라고 할 수 있습니다. 그래서, 영화를 통해서 제작이 된 작품들이 많으며, 이번에 소개를 해드리는 영화 역시 애거서 크리...
#
#
# <나일강의 죽음>도 코로나 때문에 예정보다 무려 11개월 뒤로 개봉일 연기 (2021년 9월 17일 개봉)
# kong**** 2020.12.13추천 0
# 곧 개봉할 최고의 영화 <원더우먼 1984>에게모든 관심들이 쏠리느라 후순위 관심사로 밀려 있긴하지만 원래 <나일강의 죽음>도 갤 가돗 주연으로케네스 브래너, 아미 해머, 아네트 베닝 등 호화캐스트와 함께 올 해 10월 말에...
#
#
# ...

# %%
#구현안됨
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup
try:
    0/0
except:
    pass
url = 'https://movie.naver.com/movie/bi/mi/point.naver?code=191547'
html = urlopen(url)
soup = BeautifulSoup(html,'html.parser')
rev = soup.find('span',{'id':'_filtered_ment_0'})
review_li=[]
for i in range(10):
    rev = soup.find('span',{'id':f'_filtered_ment_{i}'})
    print(rev.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-296-5bd242287174> in <module>
#      14 for i in range(10):
#      15     rev = soup.find('span',{'id':f'_filtered_ment_{i}'})
# ---> 16     print(rev.text)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.naver?code=136873&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1'
html = urlopen(url)
soup = BeautifulSoup(html,'html.parser')

review = soup.find('span',{'id':'_filtered_ment_0'})
review.get_text().strip()
review_list=[]
for i in range(10):
    review = soup.find('span',{'id':f'_filtered_ment_{i}'})
    print(f'{i+1} 번째 리뷰')
    print(review.get_text().strip())
# Out:
# 1 번째 리뷰
# 올라프의 1편요약이 기가맥힙니다
# 2 번째 리뷰
# 크리스토퍼 뮤비에서 좀 흠칫함
# 3 번째 리뷰
# 미래가 보이지 않을 때는 지금 해야할 일을 해야 해
# 4 번째 리뷰
# 나는 개인적으로 2편이 더 좋았음. 더 깊어진 스토리에 아름다워진 영상미. 한번 더 볼 의향 있음.
# 5 번째 리뷰
# 엘사옷 보고 어머니들 긴장하는 영화
# 6 번째 리뷰
# 애기들 울고 떠들고 하는거 보고 엘사 마법으로 얼릴뻔 했네요
# 7 번째 리뷰
# 크리스토퍼 혹시 과거에 뮤비찍어본적 있니?왜 이렇게 잘해??...순간 당황했잖아
# 8 번째 리뷰
# 백마탄 엘사님 Show yourself 장면 진짜 개오집니다 단언컨데 제2의 렛잇고는 into the unknown 아니고 Show yourself 입니다
# 9 번째 리뷰
# 엘사 물 속에서 말타고 나올 때 대박ㅋㅋㅋㅋ
# 10 번째 리뷰
# 겨울왕국 역시는 역시였다. OST도 1편만큼이나 중독성있다고 생각함ㅋㅋㅋ1편만큼 존잼임

# %%
#10페이지까지 넘기기
review_list=[]
for page in range(1,11):
    url = f'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136873&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page={page}'
    html = urlopen(url)
    soup = BeautifulSoup(html,'html.parser')
    for i in range(10):
        review = soup.find('span',{'id':f'_filtered_ment_{i}'})
        review =review.get_text().strip()
        review_list.append(review)
review_list
# Out:
# ['올라프의 1편요약이 기가맥힙니다',
#  '크리스토퍼 뮤비에서 좀 흠칫함',
#  '미래가 보이지 않을 때는 지금 해야할 일을 해야 해',
#  '나는 개인적으로 2편이 더 좋았음. 더 깊어진 스토리에 아름다워진 영상미. 한번 더 볼 의향 있음.',
#  '엘사옷 보고 어머니들 긴장하는 영화',
#  '애기들 울고 떠들고 하는거 보고 엘사 마법으로 얼릴뻔 했네요',
#  '크리스토퍼 혹시 과거에 뮤비찍어본적 있니?왜 이렇게 잘해??...순간 당황했잖아',
#  '백마탄 엘사님 Show yourself 장면 진짜 개오집니다 단언컨데 제2의 렛잇고는 into the unknown 아니고 Show yourself 입니다',
#  '엘사 물 속에서 말타고 나올 때 대박ㅋㅋㅋㅋ',
#  '겨울왕국 역시는 역시였다. OST도 1편만큼이나 중독성있다고 생각함ㅋㅋㅋ1편만큼 존잼임',
#  '스포 때문에 메인 넘버를 into the unknown으로 정한 느낌... 진짜 하이라이트는 show yourself 엄마와 함께 부르는 듀엣씬입니다. 이 장면만으로도 충분히 영화관에서 볼 가치가 있어요. 보고 난 ...',
#  '디즈니가 얼마나 팬을 생각하는지 알수있는 영화...1편 아동용 영화에서 1편을 보고 자란 성인들까지 보는데 재미를 느낄수 있게 만드는 2편',
#  '올라프가 다한 영화입니다',
#  '겨울왕국 2 역시 디즈니 입니다.영상미 하나만 가지고도 정말 인생 애니작을 본거에요 와 1편에서 렛잇고 열풍 이었다면 2편은 노래 영상 감동 스토리 모두를 갖추었네요 1편보다 더 훌륭합니다.꼭보세요 정말 최고네요.',
#  '렛잇고가 대박쳐서 그런지 이번에 노래가 과하게 많다.',
#  "이토록 완벽한 속편이라니. 여전히 아름답고 황홀한 스케일과 OST. '역시 믿고 보는 디즈니' 라는 말이 절로 나온다. 그렇게 부모와 어른이들의 통장은 또 한번 굿즈로 탈탈탈...",
# ...

# %%
#파일 저장하기
import urllib
review_list = []
for page in range(1,11):
    url = f'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136873&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page={page}'
    html = urlopen(url)
    soup = BeautifulSoup(html,'html.parser')
    for i in range(10):
        review = soup.find('span',{'id':f'_filtered_ment_{i}'})
        review = review.get_text().strip()
        review_list.append(review)

# with open을 활용하여 따로 file을 열고 닫기 하지 않아도 된다.
# 'w'는 file write 기능
# encoding='utf-8' => utf-8형식으로 저장
with open('./naver_movie.txt','w',encoding='utf-8') as f:
    for single_review in review_list:
        f.write(single_review+'\n')

del review_list # 메모리 절약을 위한 리스트 삭제
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5669f02b51f8> in <module>
#       4 for page in range(1,11):
#       5     url = f'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=136873&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page={page}'
# ----> 6     html = urlopen(url)
#       7     soup = BeautifulSoup(html,'html.parser')
#       8     for i in range(10):
#
# NameError: name 'urlopen' is not defined

# %%
html="""
<head>
    <title>crawler</title>
</head>
<body>
    <p class="a" align="center"> text1</p>
    <p class="b" align="center"> text2</p>
    <p class="c" align="center"> text3</p>
    <div>
        <img src="/source" width="300" height="200">
    </div>
</body>
</html>
"""
soup = BeautifulSoup(html,'html.parser')
contents = soup.find('body')
print(contents)
# Out:
# <body>
# <p align="center" class="a"> text1</p>
# <p align="center" class="b"> text2</p>
# <p align="center" class="c"> text3</p>
# <div>
# <img height="200" src="/source" width="300"/>
# </div>
# </body>

# %%
# 자식vs자손
#for d in contents.descendants:
    #print(d)

for child in contents.children:
    print(child)
# Out:
# <p align="center" class="a"> text1</p>
#
#
# <p align="center" class="b"> text2</p>
#
#
# <p align="center" class="c"> text3</p>
#
#
# <div>
# <img height="200" src="/source" width="300"/>
# </div>

# %%
for d in contents.descendants:
    print(d)
# Out:
# <p align="center" class="a"> text1</p>
#  text1
#
#
# <p align="center" class="b"> text2</p>
#  text2
#
#
# <p align="center" class="c"> text3</p>
#  text3
#
#
# <div>
# <img height="200" src="/source" width="300"/>
# </div>
#
#
# <img height="200" src="/source" width="300"/>

# %%
img_tag = contents.find('img')
print(img_tag,'\n')
print(img_tag.parent)
# Out:
# <img height="200" src="/source" width="300"/>
#
# <div>
# <img height="200" src="/source" width="300"/>
# </div>

# %%
#조상
list(img_tag.parents)
# Out:
# [<div>
#  <img height="200" src="/source" width="300"/>
#  </div>,
#  <body>
#  <p align="center" class="a"> text1</p>
#  <p align="center" class="b"> text2</p>
#  <p align="center" class="c"> text3</p>
#  <div>
#  <img height="200" src="/source" width="300"/>
#  </div>
#  </body>,
#
#  <head>
#  <title>crawler</title>
#  </head>
#  <body>
#  <p align="center" class="a"> text1</p>
#  <p align="center" class="b"> text2</p>
#  <p align="center" class="c"> text3</p>
#  <div>
#  <img height="200" src="/source" width="300"/>
#  </div>
#  </body>
#  ]

# %%
print(img_tag.find_parent('body'))
# Out:
# <body>
# <p align="center" class="a"> text1</p>
# <p align="center" class="b"> text2</p>
# <p align="center" class="c"> text3</p>
# <div>
# <img height="200" src="/source" width="300"/>
# </div>
# </body>

# %%
print(img_tag.find_parent('body'),'\n')
print(img_tag.find_parent('div'))
# Out:
# <body>
# <p align="center" class="a"> text1</p>
# <p align="center" class="b"> text2</p>
# <p align="center" class="c"> text3</p>
# <div>
# <img height="200" src="/source" width="300"/>
# </div>
# </body>
#
# <div>
# <img height="200" src="/source" width="300"/>
# </div>

# %%
#p태그값 선택지정
#p_tag =soup.find_all('p')
p_tag =soup.find_all('p',class_=['b','c'])
p_tag
# Out:
# [<p align="center" class="b"> text2</p>,
#  <p align="center" class="c"> text3</p>]

# %%
p_tag =soup.find_all('p',attrs={'class':{'b','c'}})
p_tag
# Out:
# [<p align="center" class="b"> text2</p>,
#  <p align="center" class="c"> text3</p>]

# %%
import requests
url = 'http://www.pythonscraping.com/pages/page3.html'
req = requests.get(url)
html=req.text
soup=BeautifulSoup(html,'html.parser')
imgg = soup.select_one('#gift1 > td:nth-child(4) > img')
print(imgg)
# Out:
# <img src="../img/gifts/img1.jpg"/>

# %%
f =imgg.find_parent()
f
# Out:
# <td>
# <img src="../img/gifts/img1.jpg"/>
# </td>

# %%
f.previous_sibling
f
# Out:
# <td>
# <img src="../img/gifts/img1.jpg"/>
# </td>

# %%
f.previous_sibling.previous_sibling
# Out:
# <td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td>

# %%
box =soup.select_one('#gift5 > td:nth-child(4) > img')
box
# Out:
# <img src="../img/gifts/img6.jpg"/>

# %%
boxm =box.find_parent()
boxm
# Out:
# <td>
# <img src="../img/gifts/img6.jpg"/>
# </td>

# %%
boxm.text
# Out:
# '\n\n'

# %%
boxm.previous_sibling
# Out:
# <td>
# $1.50
# </td>

# %%
#여러태그 가져오기
html = requests.get('https://www.naver.com/')
html =html.text
bs = BeautifulSoup(html,'html.parser')

hlists =bs.findAll({'h1','h2','h3','h4','h5','h6'})
for h in hlists:
    print(h)
# Out:
# <h1 class="logo_default">
# <a class="logo_naver" data-clk="top.logo" href="/"><span class="blind">네이버</span></a>
# </h1>
# <h2 class="blind">뉴스스탠드</h2>
# <h2 class="blind">주제별 캐스트</h2>
# <h2 class="title"><span class="blind">BEIJING 2022</span></h2>
# <h2 class="blind">Sign in</h2>
# <h2 class="blind">타임스퀘어</h2>
# <h3 class="title"><a href="https://www.naver.com/NOTICE">공지사항</a> </h3>
# <h3 class="title">Creators</h3>
# <h3 class="title">Partners</h3>
# <h3 class="title">Developers</h3>
# <h3 class="blind">네이버 정책 및 약관</h3>

# %%
hlists =bs.findAll({'h1','h2','h3','h4','h5','h6'}).text=('뉴스스탠드','타임스퀘어')
hlists
# Out:
# ('뉴스스탠드', '타임스퀘어')

# %%
ttls = bs.findAll(id ='NM_NEWSSTAND_TITLE')
for t in ttls:
    print(t.text)
# Out:
#  뉴스스탠드  구독한 언론사 전체언론사    리스트형  썸네일형  설정

# %%
import re
url='https://www.dataq.or.kr/www/sub/a_07.do'
req = requests.get(url)
html=req.text
soup=BeautifulSoup(html,'html.parser')
con = soup.select('#tab1')
for c in con:
    print(c.text)
li1 = re.sub('\n\n','\n',con)
print(li1)
# li2 = re.sub('\n\n','\n',li1)
# print(li2)
# Out:
# 국가기술자격
#
#
# 관련 근거
#
# 국가기술자격법 및 동법 시행령
#
#
#
# 빅데이터분석기사 정의
#
# 빅데이터 이해를 기반으로 빅데이터 분석 기획, 빅데이터 수집·저장·처리, 빅데이터 분석 및 시각화를 수행하는 실무자를 말한다.
#
#
#
# 빅데이터분석기사의 필요성
#
# 전 세계적으로 빅데이터가 미래성장동력으로 인식돼, 각국 정부에서는 관련 기업투자를 끌어내는 등 국가·기업의 주요 전략분야로 부상하고 있다.
#  국가와 기업의 경쟁력 확보를 위해 빅데이터 분석 전문가의 수요는 증가하고 있으나, 수요 대비 공급 부족으로 인력 확보에 어려움이 높은 실정이다.
# 이에 정부차원에서 빅데이터 분석 전문가 양성과 함께 체계적으로 역량을 검증할 수 있는 국가기술자격 수요가 높은 편이다.
#
#
#
# 빅데이터분석기사의 직무
#
# 대용량의 데이터 집합으로부터 유용한 정보를 찾고 결과를 예측하기 위해 목적에 따라 분석기술과 방법론을 기반으로 정형/비정형 대용량 데이터를 구축, 탐색, 분석하고 시각화를 수행하는 업무를 수행한다.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-2431f4ae616a> in <module>
#       7 for c in con:
#       8     print(c.text)
# ----> 9 li1 = re.sub('\n\n','\n',con)
#      10 print(li1)
#      11 # li2 = re.sub('\n\n','\n',li1)
#
# ~\anaconda3\lib\re.py in sub(pattern, repl, string, count, flags)
# ...

# %%
lis = bs1.findAll({'h3','h4','p'},limit=11)
for i in lis:
    print(i.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-be21f544d57a> in <module>
# ----> 1 lis = bs1.findAll({'h3','h4','p'},limit=11)
#       2 for i in lis:
#       3     print(i.text)
#       4
#       5
#
# NameError: name 'bs1' is not defined

# %%
for i in lis[:11]
# Out:
#   File "<ipython-input-20-235a7f0b9907>", line 1
#     for i in lis[:11]
#                      ^
# SyntaxError: invalid syntax

# %%
#[과제] 공백 없이 출력하기
# ex)국가기술자격
# 관련 근거
# 국가기술자격법 및 동법 시행령
# 빅데이터분석기사 정의
# 빅데이터 이해를 기반으로 빅데이터 분석 기획, 빅데이터 수집·저장·처리, 빅데이터 분석 및 시각화를 수행하는 실무자를 말한다.
# 빅데이터분석기사의 필요성

# %%
url='https://www.pythonscraping.com/pages/warandpeace.html'
url_req=requests.get(url).text
bs =BeautifulSoup(url_req,'html.parser')
print(bs.prettify())
# Out:
# <html>
#  <head>
#   <style>
#    .green{
# 	color:#55ff55;
# }
# .red{
# 	color:#ff5555;
# }
# #text{
# 	width:50%;
# }
#   </style>
#  </head>
#  <body>
#   <h1>
#    War and Peace
#   </h1>
#   <h2>
#    Chapter 1
#   </h2>
#   <div id="text">
#    "
#    <span class="red">
#     Well, Prince, so Genoa and Lucca are now just family estates of the
# Buonapartes. But I warn you, if you don't tell me that this means war,
# if you still try to defend the infamies and horrors perpetrated by
# that Antichrist- I really believe he is Antichrist- I will have
# nothing more to do with you and you are no longer my friend, no longer
# my 'faithful slave,' as you call yourself! But how do you do? I see
# I have frightened you- sit down and tell me all the news.
#    </span>
#    "
#    <p>
#    </p>
#    It was in July, 1805, and the speaker was the well-known
#    <span class="green">
#     Anna
# Pavlovna Scherer
#    </span>
#    , maid of honor and favorite of the
# ...

# %%
d1= bs.find(id='text')
# print(d1.text)
d2 = bs.findAll('span',{'class':{'green':'red'}})
for i,d in enumerate(d2):
    print(f'No.{i+1}: \n{d.text}','\n')
# Out:
# No.1:
# Anna
# Pavlovna Scherer
#
# No.2:
# Empress Marya
# Fedorovna
#
# No.3:
# Prince Vasili Kuragin
#
# No.4:
# Anna Pavlovna
#
# No.5:
# St. Petersburg
#
# No.6:
# the prince
#
# No.7:
# Anna Pavlovna
#
# No.8:
# Anna Pavlovna
#
# No.9:
# the prince
#
# No.10:
# the prince
#
# No.11:
# the prince
#
# No.12:
# Prince Vasili
#
# No.13:
# Anna Pavlovna
#
# No.14:
# Anna Pavlovna
#
# No.15:
# the prince
#
# No.16:
# Wintzingerode
#
# No.17:
# King of Prussia
#
# No.18:
# le Vicomte de Mortemart
#
# No.19:
# Montmorencys
#
# No.20:
# Rohans
#
# No.21:
# Abbe Morio
#
# No.22:
# the Emperor
#
# No.23:
# the prince
#
# No.24:
# Prince Vasili
#
# No.25:
# Dowager Empress Marya Fedorovna
#
# No.26:
# the baron
#
# No.27:
# Anna Pavlovna
#
# No.28:
# the Empress
#
# No.29:
# the Empress
#
# No.30:
# Anna Pavlovna's
#
# No.31:
# Her Majesty
#
# No.32:
# Baron
# Funke
#
# No.33:
# The prince
#
# No.34:
# Anna
# Pavlovna
#
# No.35:
# the Empress
#
# No.36:
# The prince
#
# No.37:
# Anatole
#
# ...

# %%
#Q.전쟁과 평화에 등장하는 모두 고유명사 출력
print(bs.find_all(string=re.compile('[^a-z[A-Z]+')))

#'[^ a-zA-Z0-9]?[0-9가-힣]+[^A-Z0-9]?'
# Out:
# ['\n', '\n', '\n.green{\n\tcolor:#55ff55;\n}\n.red{\n\tcolor:#ff5555;\n}\n#text{\n\twidth:50%;\n}\n', '\n', '\n', '\n', 'War and Peace', '\n', 'Chapter 1', '\n', '\n"', "Well, Prince, so Genoa and Lucca are now just family estates of the\nBuonapartes. But I warn you, if you don't tell me that this means war,\nif you still try to defend the infamies and horrors perpetrated by\nthat Antichrist- I really believe he is Antichrist- I will have\nnothing more to do with you and you are no longer my friend, no longer\nmy 'faithful slave,' as you call yourself! But how do you do? I see\nI have frightened you- sit down and tell me all the news.", '"\n', '\nIt was in July, 1805, and the speaker was the well-known ', 'Anna\nPavlovna Scherer', ', maid of honor and favorite of the ', 'Empress Marya\nFedorovna', '. With these words she greeted ', 'Prince Vasili Kuragin', ', a man\nof high rank and importance, who was the first to arrive at her\nreception. ', 'Anna Pavlovna', ' had had a cough for s
# ...

# %%
D=bs.findAll('span','green')
print(len(D))
for d in D:
    print(d.text)
# Out:
# 41
# Anna
# Pavlovna Scherer
# Empress Marya
# Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# the prince
# Anna Pavlovna
# Anna Pavlovna
# the prince
# the prince
# the prince
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# the prince
# Wintzingerode
# King of Prussia
# le Vicomte de Mortemart
# Montmorencys
# Rohans
# Abbe Morio
# the Emperor
# the prince
# Prince Vasili
# Dowager Empress Marya Fedorovna
# the baron
# Anna Pavlovna
# the Empress
# the Empress
# Anna Pavlovna's
# Her Majesty
# Baron
# Funke
# The prince
# Anna
# Pavlovna
# the Empress
# The prince
# Anatole
# the prince
# The prince
# Anna
# Pavlovna
# Anna Pavlovna

# %%
def check(text):
    checking = ('the','The','her','Her','his','His','its','Its')
    checking2 = ("'s")
    if text.startswith(checking) == False and text.endswith(checking2) == False:
        print(text)

for i in d2:
    i = i.text.replace('\n',' ')
    check(i)
# Out:
# Anna Pavlovna Scherer
# Empress Marya Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# St. Petersburg
# Anna Pavlovna
# Anna Pavlovna
# Prince Vasili
# Anna Pavlovna
# Anna Pavlovna
# Wintzingerode
# King of Prussia
# le Vicomte de Mortemart
# Montmorencys
# Rohans
# Abbe Morio
# Prince Vasili
# Dowager Empress Marya Fedorovna
# Anna Pavlovna
# Baron Funke
# Anna Pavlovna
# Anatole
# Anna Pavlovna
# Anna Pavlovna

# %%
import re
data=bs.find(id='text').text
data=re.sub('\n',' ',data)
result=re.findall('(([A-Z]([a-z]+|\.+))+(\s[A-Z][a-z]+)+)|([A-Z]{2,})|([a-z][A-Z])[a-z]*[A-Z][a-z]*',data)
for i in result:
    print(i[0])
# Out:
# Anna Pavlovna Scherer
# Empress Marya Fedorovna
# Prince Vasili Kuragin
# Anna Pavlovna
# Annette Scherer
# Anna Pavlovna
# Anna Pavlovna
# Prince Vasili
# Anna Pavlovna Scherer
# Anna Pavlovna
# Emperor Alexander
# The English
# Abbe Morio
# Dowager Empress
# Baron Funke
# Prince Vasili
# Dowager Empress Marya Fedorovna
# Anna Pavlovna
# Baron Funke
# Dowager Empress
# Anna Pavlovna
# Her Majesty
# Baron Funke
# Anna Pavlovna
# Her Majesty
# Anna Pavlovna
# Anna Pavlovna

# %%
lists = bs.findAll({'h1','h2','h3','h4','h5','h6'})
list(lists)
# Out:
# [<h1>War and Peace</h1>, <h2>Chapter 1</h2>]

# %%
# 정규표현식 +bs4
url='http://www.pythonscraping.com/pages/page3.html'
html = requests.get(url).text
bs = BeautifulSoup(html,'html.parser')
images = bs.findAll('img')
list(images)
# Out:
# [<img src="../img/gifts/logo.jpg" style="float:left;"/>,
#  <img src="../img/gifts/img1.jpg"/>,
#  <img src="../img/gifts/img2.jpg"/>,
#  <img src="../img/gifts/img3.jpg"/>,
#  <img src="../img/gifts/img4.jpg"/>,
#  <img src="../img/gifts/img6.jpg"/>]

# %%
images = bs.findAll('img', {'src':re.compile('\.\.\/img.*\.jpg')}) #.앞에 역슬래시는 .을 인식하겠다 
for image in images:
    print(image['src'])
# Out:
# ../img/gifts/logo.jpg
# ../img/gifts/img1.jpg
# ../img/gifts/img2.jpg
# ../img/gifts/img3.jpg
# ../img/gifts/img4.jpg
# ../img/gifts/img6.jpg

# %%
spans= bs.findAll('span')
list(spans)
# Out:
# [<span class="excitingNote">Now with super-colorful bell peppers!</span>,
#  <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>,
#  <span class="excitingNote">Also hand-painted by trained monkeys!</span>,
#  <span class="excitingNote">Or maybe he's only resting?</span>,
#  <span class="excitingNote">Keep your friends guessing!</span>]

# %%
bs.find_all(lambda tag:tag.get_text() =="Or maybe he's only resting?")
# Out:
# [<span class="excitingNote">Or maybe he's only resting?</span>]

# %%
spans= bs.findAll('span',{'class':re.compile('A+')})
for s in spans:
    print(s['span'])

# %%
fp =open('books.html',encoding='utf-8')
soup = BeautifulSoup(fp,'html.parser')
soup
# Out:
# <ul id="bible">
# <li id="ge">Genesis</li>
# <li id="ex">Exodus</li>
# <li id="le">Leviticus</li>
# <li id="nu">Numbers</li>
# <li id="de">Deuteronomy</li>
# </ul>

# %%
fn =soup.find(string='Numbers')
fn
# Out:
# 'Numbers'

# %%
fa =soup.find('li',attrs={'id':'nu'})
fa.text
# Out:
# 'Numbers'

# %%
fb =soup.find('li',attrs={'id':'de'})
fb.previous_sibling.previous_sibling.text
# Out:
# 'Numbers'

# %%
fc =soup.find('li',attrs={'id':'le'})
fc.next_sibling.next_sibling.text
# Out:
# 'Numbers'

# %%
fd =soup.select_one('li#nu')
print(fd)
# Out:
# <li id="nu">Numbers</li>

# %%
soup.select('li')[3].text
# Out:
# 'Numbers'

# %%
soup.find_all('li')[3].text
# Out:
# 'Numbers'

# %%
soup.select('li')[3].text
# Out:
# 'Numbers'

# %%
soup.find(lambda tag:tag.get_text() =='Numbers').text
# Out:
# 'Numbers'

# %%
soup.find('li',{'id':re.compile('nu+')}).text
# Out:
# 'Numbers'

# %%
list(soup.find('ul').children)
# Out:
# ['\n',
#  <li id="ge">Genesis</li>,
#  '\n',
#  <li id="ex">Exodus</li>,
#  '\n',
#  <li id="le">Leviticus</li>,
#  '\n',
#  <li id="nu">Numbers</li>,
#  '\n',
#  <li id="de">Deuteronomy</li>,
#  '\n']

# %%
sel =lambda q: print(soup.select_one(q).string)
sel('#nu') 
sel('li#nu')   
sel('ul >li#nu')   
sel('#bible #nu')  
sel('#bible > #nu')   
sel('ul#bible > li#nu')  
sel('li[id="nu"]')      
sel('li:nth-of-type(4)')
# Out:
# Numbers
# Numbers
# Numbers
# Numbers
# Numbers
# Numbers
# Numbers
# Numbers

# %% [markdown]
# 고객서비스를 기존방식이 아니라 ai기반 솔류션 <- 여러가지 기술이 필요하잖아
# sds 각사업부 해외쪽도 다 모아서 솔류션만들어서 제안하다고
# 좋은 솔류션을 만들려며는 비용이 많이 들잖아
# 정말 좋은 거는 얼마든지 만들 수 있어 얼마나 효율적으로 만드느냐가 어렵다는거지
# 이용가능한 솔류션이 어떤 것들이 있는데 가장 중요한 문제가 뭔지 define하는거야
# 우리가 해야되는 과제가 명확해지져.
#
#
# A,B,C 방식
# C가 가장 효과적인데 비용측면 역시 생각해야돼 B가 C보다 조금 덜 효율적인데 비용은 덜 들어
# 그럼 종합적으로 생각해서 가장 최적인 거 => 그게 가치인거지
# 마케팅 하면서 어떤 측면에서 어떤 가치를 지니는지를 염두해두고 해야돼
# 쓸데없는 일을 하면 안돼 그건 기획을 잘해야돼 기획력이 약해

# %% [markdown]
# #### urllib 모듈이란: 파이썬의 표준 모듈로서 url을 다루기 위한 모듈 패키지
# - 설치가 필요하지 않고 import urllib으로 활용
# - requests 모듈과 마찬가지로 url과 관련된 여러가지 기능들을 제공(하위 모듈)
#     - request: URL을 열고 읽는 모듈(HTTP 요청)
#     - error: request모듈에서 발생하는 에러들을 포함하는 모듈
#     - parse : URL을 파싱하는 모듈 (URL 해석 및 조작)
#     - robots.txt 파일을 파싱하는 모듈

# %%
import urllib

url='https://www.naver.com'
request = urllib.request.Request(url)
print(request)
print(request.full_url)
print(request.type)
print(request.host)
# Out:
# ...
# https://www.naver.com
# https
# www.naver.com

# %%
response1 = urllib.request.urlopen(request) # req = requests.get(url) 과 같음
print(response1)
print(response1.geturl)
print(response1.getheaders())
# Out:
# ...
# <bound method HTTPResponse.geturl of <http.client.HTTPResponse object at 0x0000015511EA2490>>
# [('Server', 'NWS'), ('Date', 'Fri, 11 Feb 2022 00:37:56 GMT'), ('Content-Type', 'text/html; charset=UTF-8'), ('Transfer-Encoding', 'chunked'), ('Connection', 'close'), ('Set-Cookie', 'PM_CK_loc=9a3f0fb3c5a75ac99ac035870f314389ee1b6f625446f14d165596c880999743; Expires=Sat, 12 Feb 2022 00:37:56 GMT; Path=/; HttpOnly'), ('Cache-Control', 'no-cache, no-store, must-revalidate'), ('Pragma', 'no-cache'), ('P3P', 'CP="CAO DSP CURa ADMa TAIa PSAa OUR LAW STP PHY ONL UNI PUR FIN COM NAV INT DEM STA PRE"'), ('X-Frame-Options', 'DENY'), ('X-XSS-Protection', '1; mode=block'), ('Strict-Transport-Security', 'max-age=63072000; includeSubdomains'), ('Referrer-Policy', 'unsafe-url')]

# %%
# read(): 인자로 전달한 숫자만큼 데이터를 읽음 
response2 = urllib.request.urlopen(url)
response2.read().decode('utf-8') # requests.get(url).text 와 같음/ read()안에 숫자가 바이트 수
#한글은 2byte
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네
# ...

# %%
# urllib.request.urlretrieve() : 웹상의 이미지 저장
import urllib.request
img_src ='https://images.unsplash.com/photo-1536329583941-14287ec6fc4e?ixlib=rb-1.2.1&ixid=MnwxMjA3fDF8MHxlZGl0b3JpYWwtZmVlZHwxfHx8ZW58MHx8fHw%3D&auto=format&fit=crop&w=600&q=60'
new_name = 'img.png'
urllib.request.urlretrieve(img_src,new_name)
# Out:
# ('img.png', <http.client.HTTPMessage at 0x155124a93d0>)

# %%
# 단순한 패턴을 읽을 때에는 복잡한 정규표현식보다는 간단한 parse모듈을 사용
# urllib.parse: URL을 6개로 분리하여 반환
import urllib
parse = urllib.parse.urlparse('https://section.blog.naver.com/Search/Post.naver?pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai')
print(parse,'\n')
print(parse[4:5],'\n')
print(parse.scheme,'\n')
# Out:
# ParseResult(scheme='https', netloc='section.blog.naver.com', path='/Search/Post.naver', params='', query='pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai', fragment='')
#
# ('pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai',)
#
# https

# %%
print(parse[0],'\n')
print(parse.scheme,'\n')
print(parse[1],'\n')
print(parse.netloc,'\n')
print(parse[2],'\n')
print(parse.path,'\n')
print(parse[3],'\n')
print(parse.params,'\n')
print(parse[4],'\n')
print(parse.query,'\n')
print(parse[5],'\n')
print(parse.fragment,'\n')
# Out:
# https
#
# https
#
# section.blog.naver.com
#
# section.blog.naver.com
#
# /Search/Post.naver
#
# /Search/Post.naver
#
#
#
#
#
# pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai
#
# pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai

# %%
#urllib.parse.urlunparse(), urllib.parse.urlunsplit()
# 튜플은 변경 불가능이기 때문에 리스트( 변경가능 )으로 변경하여 활용
parse = urllib.parse.urlparse('https://blog.naver.com/koreatech91;a=1?b=2#b')
print(parse)
parse = list(parse)
parse[1] = 'blog.daum.net'
parse
unparse = urllib.parse.urlunparse(parse)
print(unparse)
# Out:
# ParseResult(scheme='https', netloc='blog.naver.com', path='/koreatech91', params='a=1', query='b=2', fragment='b')
# https://blog.daum.net/koreatech91;a=1?b=2#b

# %%
# parse_qs(), parse_qsl()
# 쿼리를 파싱해서 사전(qs) 및 리스트(qs)로 변환, 쿼리를 변경하여 요청시 활용
parse = urllib.parse.urlparse('https://blog.naver.com/koreatech91;a=1?b=2#b')
print(parse.query)
# 사전
qs = urllib.parse.parse_qs(parse.query)
print(qs,type(qs))
# 리스트
qsl = urllib.parse.parse_qsl(parse.query)
print(qsl,type(qsl))
# Out:
# b=2
# {'b': ['2']} <class 'dict'>
# [('b', '2')] <class 'list'>

# %%
# urljoin(a,b) : a와 b  url을 합쳐주는 기능. '/'에 따라 url 주소가 달라짐
url = 'https://naver.com/a/b'
print(urllib.parse.urljoin(url,'c'))
print(urllib.parse.urljoin(url,'/c'))
url2 = 'https://naver.com/a/b/'
print(urllib.parse.urljoin(url2,'c'))
print(urllib.parse.urljoin(url2,'/c'))
# Out:
# https://naver.com/a/c
# https://naver.com/c
# https://naver.com/a/b/c
# https://naver.com/c

# %%
# quote(),unquote(): 아스키코드가 아닌 퍼센트 인코딩으로 변환
# 퍼센트 인코딩은 url에 문자를 표현하는 문자 인코딩 방법
#url에 한글이 섞이면 오류 발생 

#퍼센트 인코딩 
print(urllib.parse.quote('파이썬'))
print(urllib.parse.unquote('%ED%8C%8C%EC%9D%B4%EC%8D%AC'))
# Out:
# %ED%8C%8C%EC%9D%B4%EC%8D%AC
# 파이썬

# %%
#  url = 'https://search.naver.com/search.naver?query="파이썬"'
url = 'https://search.naver.com/search.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC'

response = urllib.request.urlopen(url)
byte_data = response.read(100)
text_data = byte_data.decode('utf-8')
print(text_data)
# Out:
# <!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always

# %%
# 홈페이지를 로컬에 파일로 저장
request = urllib.request.Request('https://www.naver.com')
data = urllib.request.urlopen(request).read()
f = open('pc.html','wb')
f.write(data)
f.close()

# %%
with open('pc.html','rb') as f:
    data= f.read().decode('utf-8')
    print(data)
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 
# ...

# %%
query_list =['파이썬','웹 크롤링','빅데이터','python']
url  ='https://search.naver.com/search.naver?query='
for i in query_list:
    new_url =url+urllib.parse.quote(i) #퍼센트 인코딩을 했고 
    response_urllib = urllib.request.urlopen(new_url)
    byte_data = response_urllib.read(400)
    text_data = byte_data.decode('utf-8')
    print(text_data,'\n')
# Out:
# <!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="파이썬 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/ss
#
# <!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="웹 크롤링 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.ne
#
# ...
