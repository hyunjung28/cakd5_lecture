# %% [markdown]
# ## 네이버 검색 API 서비스

# %% [markdown]
# ### 네이버 웹문서 검색 API

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "qjCFQhUui0fUZxNVWQ48"
client_secret = "QqnmmMUCk0"
encText = urllib.parse.quote("음원재생")  #(퍼센트 인코딩 )
# query = urllib.parse.qoute(input('검색 질의:'))
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret )
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Fri, 18 Feb 2022 16:14:54 +0900",
# "total": 123253,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "아이폰 무손실 <b>음원</b>을 무선으로 <b>재생</b>해도 음질이 괜찮네요?",
# "link": "https:\/\/blog.naver.com\/yagbossi?Redirect=Log&logNo=222485964383",
# "description": "늦게나마 아이폰 무손실 <b>음원 재생</b> 기능이 생각보다 괜찮아서 다행이었습니다. 보유 중인 많은 CD들... CD아니고 음원파일 재생 아니고 애플뮤직같이 스트리밍으로 무손실 음원을 재생해서 들으면 CD음질에... ",
# "bloggername": "영리한 운동을 하자!!!",
# "bloggerlink": "https://blog.naver.com/yagbossi",
# "postdate": "20210827"
#
# },
# {
# "title": "휴대폰 <b>음원 재생</b> 앱 분석 #1",
# "link": "https:\/\/blog.naver.com\/1997918?Redirect=Log&logNo=222065169576",
# "description": "재생 기기 : 삼성 갤럭시 노트 8 2. <b>음원 재생</b> 앱 - Foobar2000 - Poweramp - Sony music center - Bugs music player 3. 분석 기기 및 분석 음원 : Lindos M20, 전용 음원 4. 분석 항목 - Frequency Response (주파수별 재생 대역)... ",
# "bloggername": "Life's like that.....",
# "bloggerlink": "https://blog.naver.com/1997918",
# "postdate": "20200819"
#
# },
# {
# ...

# %%
import os
import sys
import urllib.request
client_id = "qjCFQhUui0fUZxNVWQ48"
client_secret = "QqnmmMUCk0"
query = urllib.parse.quote(input('검색 질의:'))#  ->  매 번 코드에서 검색값 바꾸는 거 보다 이렇게 변수를 하나 줘서 
# 검색어를 받는 것을 선언
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret )
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# 검색 질의:음원 재생
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1353             try:
# -> 1354                 h.request(req.get_method(), req.selector, req.data, headers,
#    1355                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ...

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "xUCzXK76sez26412vcLf"
client_secret = "oCZNcdIe3A"
# encText = urllib.parse.quote("빅데이터")
query = urllib.parse.quote(input("검색 질의: "))

idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=('Title','Link','Description'))

for start_index in range(start, end, display):
    url = "https://openapi.naver.com/v1/search/blog?query=" + query \
    + "&display=" + str(display) \
    + "&start=" + str(start_index)
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, "", items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            web_df.loc[idx] = [title, link, description]
            idx += 1        
    else:
        print("Error Code:" + rescode)
web_df
# Out:
# 검색 질의: 플레이리스트
#                                                  Title  \
# 0                    1월의 재재네집, 집 그리고 플레이리스트 #거실인테리어 기록
# 1                            멜론 플레이리스트 삭제 및 추가 하는 방법은?
# 2                         FLO 플로로 나만의 플레이리스트와 오디오 디깅하기
# 3                 FLO 플레이리스트 취향대로 짜주고 오디오콘텐츠까지 있어서...
# 4                                   오디오앱 플로 플레이리스트 알차다
# ..                                                 ...
# 995                     [PNU 문화] 봄의 시작과 개강을 알리는 플레이리스트
# 996                    생지와 다람쥐 똥으로 시작한 아침식사 + 모닝플레이리스트
# 997  [씬디's 플레이리스트] 5월 &quot;너무 어른이 된 거 같을 때&quot; b...
# 998                   [적재 Jukae] 할 거 없을 때 듣기 좋은 플레이리스트
# 999            [음악 추천] 분위기 깡패 플레이리스트 추천!! 신나는 음악부터...
#
#                                                   Link  \
# 0    https://blog.naver.com/chanchan2nd?Redirect=Lo...
# 1    https://blog.naver.com/swifty_7?Redirect=Log&l...
# 2    https://blog.naver.com/hong_blossom?Redirect=L...
# 3    https://blog.naver.com/hwanghwoo?Redirect=Log&...
# ...

# %%
import json 
json.loads(response_body).keys()
# Out:
# dict_keys(['lastBuildDate', 'total', 'start', 'display', 'items'])

# %%
items = json.loads(response_body)['items']
items[3]
# Out:
# {'title': '네이버 브랜드<b>검색</b>광고 모바일 상품 개편.. 금액도?',
#  'link': 'https://blog.naver.com/yong_tj?Redirect=Log&logNo=222642235336',
#  'description': 'ㅠㅠ 많은 브랜드사들이 자사 네이버 브랜드 <b>검색</b>광고를 진행을 하시고 계시지요. 참으로 짜증나는 일이 아닐 수 없습니다. 화장품 브랜드나, 의류 브랜드사들은 자사몰에 대한 <b>검색</b>쿼리를 온전히 다 잡기... ',
#  'bloggername': '온라인광고는용팀장',
#  'bloggerlink': 'https://blog.naver.com/yong_tj',
#  'postdate': '20220208'}

# %%
#[과제] 뉴스,책,쇼핑,영화,지식in, 등 2개이상의 카테고리를 선택하여 관심 데이터를 1000개까지 출력하세요

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re 

client_id = "qjCFQhUui0fUZxNVWQ48"
client_secret = "QqnmmMUCk0"

query = urllib.parse.quote(input('검색 질의:'))

idx= 0
display=100
start=1
end=1000

news_df =pd.DataFrame(columns={'Title','pubDate','description'})

for start_index in range(start,end,display):
    url = "https://openapi.naver.com/v1/search/cafearticle?query="  + query \
  + "&display=" + str(display) \
    + "&start=" + str(start_index)
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret )
    response = urllib.request.urlopen(request)

    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items= response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag =re.compile('<.*?>')
            title =re.sub(remove_tag,"",items[item_index]['title'])
            description =re.sub(remove_tag,'',items[item_index]['description'])
            news_df.loc[idx]= [title,description]
            idx +=1
        
    else:
        print("Error Code:" + rescode)
news_df
# Out:
# 검색 질의:플레이리스트
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-b7dc4db9fb3e> in <module>
#      36             title =re.sub(remove_tag,"",items[item_index]['title'])
#      37             description =re.sub(remove_tag,'',items[item_index]['description'])
# ---> 38             news_df.loc[idx]= [title,description]
#      39             idx +=1
#      40
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 692         iloc._setitem_with_indexer(indexer, value, self.name)
#     693
#     694     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1627
#    1628             if missing:
# ...

# %%
#뉴스 API
import os
import sys
import urllib.request
client_id = "qjCFQhUui0fUZxNVWQ48"
client_secret = "QqnmmMUCk0"
encText = urllib.parse.quote("빅데이터")  #(퍼센트 인코딩 )
# query = urllib.parse.qoute(input('검색 질의:'))
url = "https://openapi.naver.com/v1/search/news?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret )
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
#    print("Error Code:" + rescode)

# %%
#지식in API
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "xUCzXK76sez26412vcLf"
client_secret = "oCZNcdIe3A"
# encText = urllib.parse.quote("빅데이터")
query = urllib.parse.quote(input("검색 질의: "))

idx = 0
display = 100
start = 1
end = 1000
sort ='sim'
kin_df = pd.DataFrame(columns=('Title','Link','Description'))

for start_index in range(start, end, display):
    url = "https://openapi.naver.com/v1/search/cafearticle?query=" + query \
    + "&display=" + str(display) \
    + "&start=" + str(start_index) \
    + "&sort="+sort
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, "", items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            kin_df.loc[idx] = [title, link, description]
            idx += 1        
    else:
        print("Error Code:" + rescode)
kin_df
# Out:
# 검색 질의: 플레이리스트
#                                   Title  \
# 0                        UAPP 플레이리스트 질문
# 1                         플레이리스트 갬성의 오워
# 2                                플레이리스트
# 3                       플레이리스트 공유 해주세요~
# 4                타이달 플레이리스트 가장 아름다운 2악장
# ..                                  ...
# 995                년 블로그에서 사랑 받은 플레이리스트
# 996            얼루어 잡지 윤하 플레이리스트 발견했어요ㅎㅎ
# 997  블투 워치로 핸드폰 음악앱 리모컨으로 활용시 플레이리스트 문의
# 998             애플뮤직 플레이리스트 다운로드 질문입니다.
# 999                      저의 ps4 플레이 리스트
#
#                                           Link  \
# 0           http://cafe.naver.com/drhp/1676289
# 1    http://cafe.naver.com/appleiphone/7185694
# 2       http://cafe.naver.com/nespresso/499376
# 3        http://cafe.naver.com/msbabys/4267156
# 4       http://cafe.naver.com/audiodudu/446474
# ..                                         ...
# 995       http://cafe.naver.com/gamecommun/300
# 996    http://cafe.naver.com/younhastory/86423
# ...

# %% [markdown]
# [과제]
#
# 아래사항에 유의하여 OpenWeatherMap 날씨정보를 웹 API로 가져와서 출력하세요
#
# https://openweathermap.org/api 사이트에서 Current Weather data에 대한 API doc 내용을 파악
#  개발자 등록을 하고 API 키 발급 받음(https://home.openweathermap.org/users/sign_up)    </dr>
# New Account 등록 후 API Keys라는 탭에서 API Key 확인 가능
#  기본적으로 유료 사이트이지만 현재 날씨, 5일까지의 날씨는 무료로 사용할 수 있음(단 1분에 60번만 호출 가능)
#  서울, 토쿄, 뉴욕의 날씨를 가져오는 프로그램 작성(text로 가져와서 json으로 변환하여 일차 출력)
# cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]
# 가져올 정보 : 도시별 날씨(description), 최저 기온(temp_min), 최고 기온(temp_max), 습도(humidity), 기압(pressure), 풍속(speed)
# 기온 데이터는 켈빈 온도로 되어 있으며 섭씨 온도로 변환해서 출력
# json 포멧으로 출력 데이터를 아래와 같이 가독력 있게 출력(소수점 2번째에서 반올림 처리)
#
# 도시 = Seoul | 날씨 = broken clouds | 최저 기온 = -1.0 2 | 최고 기온 = 2.0 2 | 습도 = 74 | 기압 = 1023 | 풍속 = 0.5

# %%
+ 도시 = Seoul
| 날씨 = clear sky
| 최저 기온 = -4.0 2
| 최고 기온 = -0.0 2
| 습도 = 70
| 기압 = 1024
| 풍속 = 2.06

+ 도시 = Tokyo
| 날씨 = mist
| 최저 기온 = -0.0 2
| 최고 기온 = 3.0 2
| 습도 = 95
| 기압 = 1016
| 풍속 = 9.26

+ 도시 = New York
| 날씨 = few clouds
| 최저 기온 = -1.0 2
| 최고 기온 = 4.0 2
| 습도 = 86
| 기압 = 1011
| 풍속 = 1.54

# %%
API key=f4b295f415b16b6d8aeb717c97643527
# Out:
#   File "<ipython-input-18-3fc672e91e27>", line 1
#     API key=f4b295f415b16b6d8aeb717c97643527
#         ^
# SyntaxError: invalid syntax

# %%
import requests
from urllib.parse import urlparse
import pandas as pd
import json
url = 'http://api.openweathermap.org/data/2.5/weather?q=Seoul&APPID=f4b295f415b16b6d8aeb717c97643527' 
k2c = lambda k: k-273.15   #화씨를 섭씨로 바꾸는 수식 
req = requests.get(url)
print(req.text)
data= json.loads(req.text)
data
# Out:
# {"coord":{"lon":126.9778,"lat":37.5683},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"base":"stations","main":{"temp":275.43,"feels_like":275.43,"temp_min":273.38,"temp_max":276.88,"pressure":1021,"humidity":67,"sea_level":1021,"grnd_level":1014},"visibility":10000,"wind":{"speed":1.22,"deg":131,"gust":1.91},"clouds":{"all":100},"dt":1644801047,"sys":{"type":1,"id":8093,"country":"KR","sunrise":1644791007,"sunset":1644829760},"timezone":32400,"id":1835848,"name":"Seoul","cod":200}
# {'coord': {'lon': 126.9778, 'lat': 37.5683},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 275.43,
#   'feels_like': 275.43,
#   'temp_min': 273.38,
#   'temp_max': 276.88,
#   'pressure': 1021,
#   'humidity': 67,
#   'sea_level': 1021,
#   'grnd_level': 1014},
#  'visibility': 10000,
#  'wind': {'speed': 1.22, 'deg': 131, 'gust': 1.91},
# ...

# %%
#서울
print('도시= ',data['name'])
print('최저기온=', k2c(data['main']['temp_min']))
print('최고기온=', k2c(data['main']['temp_max']))
print('습도=', data['main']['humidity'])
print('기압=', data['main']['pressure'])
print('풍속=', data['wind']['speed'])
# Out:
# 도시=  Seoul
# 최저기온= 6.760000000000048
# 최고기온= 8.730000000000018
# 습도= 33
# 기압= 1025
# 풍속= 3.09

# %%
import requests
from urllib.parse import urlparse
import pandas as pd
import json
url = 'http://api.openweathermap.org/data/2.5/weather?q=Tokyo&APPID=f4b295f415b16b6d8aeb717c97643527' 
req = requests.get(url)
data1= json.loads(req.text)
data1
# Out:
# {'coord': {'lon': 139.6917, 'lat': 35.6895},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 279.98,
#   'feels_like': 275.95,
#   'temp_min': 278.99,
#   'temp_max': 280.81,
#   'pressure': 1021,
#   'humidity': 65},
#  'visibility': 10000,
#  'wind': {'speed': 7.2, 'deg': 60},
#  'clouds': {'all': 20},
#  'dt': 1644569261,
#  'sys': {'type': 2,
#   'id': 2038398,
#   'country': 'JP',
#   'sunrise': 1644528783,
#   'sunset': 1644567483},
#  'timezone': 32400,
#  'id': 1850144,
#  'name': 'Tokyo',
#  'cod': 200}

# %%
print('도시= ',data1['name'])
print('최저기온=', k2c(data1['main']['temp_min']))
print('최고기온=', k2c(data1['main']['temp_max']))
print('습도=', data1['main']['humidity'])
print('기압=', data1['main']['pressure'])
print('풍속=', data1['wind']['speed'])
# Out:
# 도시=  Tokyo
# 최저기온= 5.840000000000032
# 최고기온= 7.660000000000025
# 습도= 65
# 기압= 1021
# 풍속= 7.2

# %%
#[팀과제] 유용한 open API를 탐색해서 이용방법과 실제 사용 사례를 소개 
# - ex) 대기오염에 관련된 open api를 이용해서 어떻게 이용하는지를 설명 하는 방식, 실제 sample로 데이터 가져오는 것을 시범 
# 팀별발표-  기획초안 하고 open API 탐색해서 이용하는 것

# %% [markdown]
# 1052274813190-fioquclfc5btssp63haduvl58v9r3h1v.apps.googleusercontent.com
# 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
