# %%
menu1='''




-----메뉴-------

1. 모두가 사랑하는 크림 파스타 1,0000원
2. 고소한 풍미 가득 라떼 5,000원

'''

menu2='''



-----메뉴-------
1. BEST 로제 파스타 1,0000원
2. 베지 맞춤 무지방 라떼 5,000원


'''



print('어서오세요식당 입니다.' + ' \n')
print("="*40)
print("="*40)







veg_pas = 10000
veg_la = 5000
pas =10000
la = 5000



choice = input('일반메뉴 비건메뉴 중 어떤 것을 보시겠습니까. 일반:1,비건:2>> ')



if choice =='1':
    print(menu1)
    
    order= input("메뉴를 선정하세요:")
    if order == '1':
        x = int(input("몇 인분을 시키시겠습니까"))
        price_sum = (pas*x)
        print(f"파스타의 가격은 {price_sum}입니다")
        add = input('추가 주문 하시겠습니까?>> y/n ')
        if add == 'y':
                print(menu1)
                add_2 = input('메뉴를 선정하세요:')
                if add_2 == '2':
                    y = int(input("몇 잔을 시키시겠습니까"))
                    price_sum2 = y*la + x*pas
                    
                 
                    print(f'주문하신 음식의 총 가격은  {price_sum2}입니다.즐거운 식사 되세요')
        elif add =='n':
                price_sum3 = pas*x
                print(f'파스타의 가격은 {price_sum3}입니다. 즐거운 식사 되세요')
                print("★다음 번에 또 방문해주세요 ★")
        else:
            print('입력 오류 입니다. y/n로만 답해주세요')
                
                
                
                
    elif order =='2':
        e = int(input("몇 잔을 시키시겠습니까"))
        price_sum4 = la*e
        print(f"라떼의 가격은  {la*e}입니다")
        
        add_3 = input('추가 주문 하시겠습니까? >> y/n :')
        if add_3 == 'y':
            print(menu1)
            add_3 = input('메뉴를 선정하세요: ')
            
            if add_3 =='1':
                f = int(input("몇 인분을 시키시겠습니까"))
                price_sum5= (pas*f)+(la)
                print(f'파스타를 추가하여 총 가격은  {price_sum5}입니다.즐거운 식사 되세요')
                print("★다음 번에 또 방문해주세요 ★")
            elif add_3 =='2':
                g = int(input("몇 잔을 시키시겠습니까?: "))
                price_sum6 = la*g
                print(f"주문하는 라떼는 {e+g}잔으로 라떼의 가격은  {la*g}입니다")
                print("★다음 번에 또 방문해주세요 ★")
        elif add_3 =='n':
                print(f"라떼의 가격은  {la*e}입니다")
                print("★다음 번에 또 방문해주세요 ★")
                
    else:
            print('잘못 입력하였습니다. 다시 입력해주세요')
       
      
else:
    print(menu2)

    order= input("메뉴를 선정하세요:")
    if order =='1':
        x_veg = int(input("몇 인분을 시키시겠습니까"))
        veg_sum = (veg_pas*x)
       
        print(f'주문하신 음식은 파스타{x_veg}인분으로 총 금액은 {veg_pas*x}원 입니다')
        v_add = input('추가 주문 하시겠습니까?>> y/n ')
        if v_add == 'y':
                print(menu2)
                
                
                vadd_2 = input('메뉴를 선정하세요:')
                if vadd_2 == '1':
                    vadd_22 =int(input("몇 인분을 시키시겠습니까"))
                    price_veg22 = x_veg*veg_pas + vadd_22*veg_pas
                    
                    price2 = veg_pas+veg_la
                    print(f'주문하신 음식은 파스타{vadd_22}인분으로 총 금액은 {price_veg22}원 입니다.')
                    print("★다음 번에 또 방문해주세요 ★")
                elif vadd_2 =='2':
                    vadd_22 = int(input("몇 잔을 시키시겠습니까"))
                    price_veg23 = x_veg*veg_pas + vadd_22*veg_la
                    print(f'주문하신 음식의 총 가격은  {price_veg23}입니다.')
                    print("★다음 번에 또 방문해주세요 ★")
        elif v_add =='n':
                price2 = veg_pas
                print(f'총가격은 {veg_pas}입니다')
                print("★다음 번에 또 방문해주세요 ★")
        else:
            print('입력 오류 입니다. y/n로만 답해주세요')       
        
        
        
        
        
    elif order =='2':
        y_veg = int(input("몇 잔을 주문하시겠습니까"))
        
        price=veg_la*y_veg
        print(f'총 금액은 {veg_la*y_veg}원 입니다')
        v  = input("추가 주문 하시겠습니까? y/n: ")
        if v_add2 =='y':
            print(menu2)
            v_add4 = input("메뉴를 선정하세요 :  ")
           
            if v_add4 =='1':
                v_add5 = int(input("몇 인분을 선택하시겠습니까? "))
                pirce4 = veg_pas*v_add5 +veg_la*y_veg
                print(f'주문하는 음식의 총 금액은 {price4}원 입니다. 즐거운 시간 되세요')
                print("★다음 번에 또 방문해주세요 ★")
            elif v_add4 =='2':
                y_veg = int(input("몇 잔을 주문하시겠습니까"))
                price = veg_la*y_veg 
                print(f'주문하신 음식의 총 금액은 {veg_la*y_veg}원 입니다. 즐거운 시간 되세요')
                print("★다음 번에 또 방문해주세요 ★")
        elif v_add2 =='n':
            price = veg_la*y_veg
            print(f'총 금액은 {price}원 입니다.즐거운 시간 되세요')
            print("★다음 번에 또 방문해주세요 ★")
    else: 
        print('입력 오류 입니다. y/n로만 답해주세요')
# Out:
# 어서오세요식당 입니다.
#
# ...
# 일반메뉴 비건메뉴 중 어떤 것을 보시겠습니까. 일반:1,비건:2>> 2
#
#
#
#
# -----메뉴-------
# 1. 베지가 가장 사랑하는 로제 파스타 1,0000원
# 2. 베지여도 먹을 수 있는 무지방 라떼 5,000원
#
#
#
# 메뉴를 선정하세요:2
# 몇 잔을 주문하시겠습니까2
# 총 금액은 10000원 입니다
# 추가 주문 하시겠습니까? y/n: y
#
#
#
#
# -----메뉴-------
# 1. 베지가 가장 사랑하는 로제 파스타 1,0000원
# 2. 베지여도 먹을 수 있는 무지방 라떼 5,000원
#
#
#
# 메뉴를 선정하세요 :  2
# 몇 잔을 주문하시겠습니까3
# 주문하신 음식의 총 금액은 15000원 입니다. 즐거운 시간 되세요
# ★다음 번에 또 방문해주세요 ★

# %%
파스타가격 a
라떼 b
베지파스타 c
price = a+b
price = a+c
# Out:
# 몇 회? : 1
# 몇 회? : 2
