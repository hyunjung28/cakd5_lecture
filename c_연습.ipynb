# %%
menu= '''

======================================================

'어세오세요 식당'입니다. 보고 싶은 메뉴판을 선택하세요.

1. 일반 메뉴판

2. 베지 메뉴판


======================================================
'''



menu1 = '''


1. 파스타 3,0000원
2. 라떼  4,000원



'''


menu3 = '''

<당신의 채식 유형을 선택해주세요>


1. 락토오보 채식 (채식, 우유, 유제품, 달걀)

2. 페스코채식 (채식,우유,달걀, 어류)

3. 락토 채식(채식,우유, 유제품)

4. 플렉시테리안(채식,육식)


'''



menu2 = '''


1. 아이스크림 3000원
2. 밀크티 5000원


'''







class Menu:
    def menu (self,num):
        price_sum=0
        while 1:
            if num ==1:
                print(menu1)

            elif num ==2:
                print(menu2)
                x = int(input('당신의 채식 유형을 선택하세요 >> '))
                if x == 1:
                    print(menu2)
                else: 
                    print(menu2)
            order = int(input("메뉴를 선택하세요 : >>"))
            if order ==1:
                y = int(input("몇 인분을 시키시겠습니까"))
                price_sum += (food[num-1][0]*y)
                print(f"주문하신 음식의 가격은 {price_sum}입니다")

            elif order ==2:
                y_2 = int(input("몇 인분을 시키시겠습니까"))
                price_sum += (food[num-1][1]*y_2)

            add = input('추가 주문 하시겠습니까?>> y/n ')
            if add == 'y':

                continue

                print(f'주문하신 음식의 총 가격은  {price_sum}입니다.즐거운 식사 되세요')
            elif add =='n':

                print(f'파스타의 가격은 {price_sum}입니다. 즐거운 식사 되세요')
                print("★다음 번에 또 방문해주세요 ★")
                break
            else:
                print('입력 오류 입니다. y/n로만 답해주세요')


            
            
            
            
            
#메인코드         
food = [(10000,5000),(3000,40000)]
price_sum=0

print(menu)
a= Menu()

want = int(input(" 메뉴판을 선택하세요 : >>>  "))
a.menu(want)
# Out:
# ======================================================
#
# '어세오세요 식당'입니다. 보고 싶은 메뉴판을 선택하세요.
#
# 1. 일반 메뉴판
#
# 2. 베지 메뉴판
#
#
# ======================================================
#
#  메뉴판을 선택하세요 : >>>  1
#
#
#
# 1. 파스타 3,0000원
# 2. 라떼  4,000원
#
#
#
#
# 메뉴를 선택하세요 : >>1
# 몇 인분을 시키시겠습니까1
# 주문하신 음식의 가격은 10000입니다
# 추가 주문 하시겠습니까?>> y/n y
#
#
#
# 1. 파스타 3,0000원
# 2. 라떼  4,000원
#
#
#
#
# 메뉴를 선택하세요 : >>1
# 몇 인분을 시키시겠습니까
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3452/4128686061.py in <module>
#     111
#     112 want = int(input(" 메뉴판을 선택하세요 : >>>  "))
# --> 113 a.menu(want)
#     114
#     115
#
# ~\AppData\Local\Temp/ipykernel_3452/4128686061.py in menu(self, num)
#      75             order = int(input("메뉴를 선택하세요 : >>"))
#      76             if order ==1:
# ---> 77                 y = int(input("몇 인분을 시키시겠습니까"))
#      78                 price_sum += (food[num-1][0]*y)
#      79                 print(f"주문하신 음식의 가격은 {price_sum}입니다")
#
# ValueError: invalid literal for int() with base 10: ''
