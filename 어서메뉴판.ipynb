# %%
menu= '''

======================================================

'어세오세요 식당'입니다. 보고 싶은 메뉴판을 선택하세요

1. 일반 메뉴판

2. 베지 메뉴판


======================================================
'''



menu1 = '''


1. 파스타 1,0000원
2. 라떼  5,000원



'''


menu2 = '''

<당신의 채식 유형을 선택해주세요>


1. 락토오보 채식 (채식, 우유, 유제품, 달걀)

2. 페스코채식 (채식,우유,달걀, 어류)

3. 락토 채식(채식,우유, 유제품)

4. 플렉시테리안(채식,육식)


'''


menu3 = '''


1.아이스크림 3000원
2.밀크티 4000원



'''
pasta =10000
latte = 5000
ice= 3000
milk = 4000

price_sum=0


print(menu)
try:
    want = int(input(" 메뉴판을 선택하세요 : >>>  "))
except ValueError:
        print('형식이 잘못되었습니다')
    
class Ment:
    var = '★다음번에 또 방문해주세요★'
    def mention(self):
        return self.var
a = Ment()




    
if want ==1:
    
    
    
    while 1:
        print(menu1)
        try: 
            order= int(input("메뉴를 선정하세요: >>>"))
            if order == 1:
                x = int(input("몇 인분을 시키시겠습니까"))
                price_sum += (pasta*x)
                print(f"주문하신 음식의 가격은 {price_sum}입니다")

            elif order ==2:
                x_2 = int(input("몇 인분을 시키시겠습니까"))
                price_sum += (latte*x_2)

            add = input('추가 주문 하시겠습니까?>> y/n ')   
            if add == 'y':
                continue
            elif add=='n':
                print(f'주문하신 음식의 가격은 {price_sum}입니다. 즐거운 식사 되세요')
                print(a.var)
                break

            else:
                    raise Exception
                    

        except ValueError:
                        print('형식이 잘못되었습니다')
        except:
                        print('다시 입력하세요')

elif want ==2:
    

   
    print(menu2) 
    choice= int(input("당신의 채식 유형을 선택하세요 : >>>"))
    while 1:
        try:
            if choice ==1:
                print(menu3)
                order = input("메뉴를 선택하세요 : >>")
                if order =='1':
                    y = int(input("몇 인분을 시키시겠습니까"))
                    price_sum += (ice*y)
                    print(f"주문하신 음식의 가격은 {price_sum}입니다")
                elif order =='2':
                    y_2 = int(input("몇 인분을 시키시겠습니까"))
                    price_sum += (milk*y_2)
                add = input('추가 주문 하시겠습니까?>> y/n ')   
                if add == 'y':
                    continue
                elif add=='n':
                    print(f'주문하신 음식의 가격은 {price_sum}입니다. 즐거운 식사 되세요')
                    print(a.var)
                    break

            else:
                    raise Exception
        except TypeError:
                    print('형식이 잘못되었습니다')
        except:
                    print('다시 입력하세요')

    while 1:      
        try:
            if choice ==2:
                print(menu3)
                order = input("메뉴를 선택하세요 : >>")
                if order =='1':
                    y = int(input("몇 인분을 시키시겠습니까"))
                    price_sum += (ice*y)
                    print(f"주문하신 음식의 가격은 {price_sum}입니다")
                elif order =='2':
                    y_2 = int(input("몇 인분을 시키시겠습니까"))
                    price_sum += (milk*y_2)
                    add = input('추가 주문 하시겠습니까?>> y/n ')   
                    if add == 'y':
                        continue
                    elif add=='n':
                        print(f'주문하신 음식의 가격은 {price_sum}입니다. 즐거운 식사 되세요')
                        print(a.var)
                        break

                else:
                        raise Exception

        except TypeError:
                        print('형식이 잘못되었습니다')
        except:
                        print('다시 입력하세요')
# Out:
# ======================================================
#
# '어세오세요 식당'입니다. 보고 싶은 메뉴판을 선택하세요
#
# 1. 일반 메뉴판
#
# 2. 베지 메뉴판
#
#
# ======================================================
#
#  메뉴판을 선택하세요 : >>>  1
#
#
#
# 1. 파스타 1,0000원
# 2. 라떼  5,000원
#
#
#
#
# 메뉴를 선정하세요: >>>h
# 형식이 잘못되었습니다
#
#
#
# 1. 파스타 1,0000원
# 2. 라떼  5,000원
#
#
#
#
# 메뉴를 선정하세요: >>>dfsd
# 형식이 잘못되었습니다
#
#
#
# 1. 파스타 1,0000원
# 2. 라떼  5,000원
#
#
#
#
# 메뉴를 선정하세요: >>>2
# 몇 인분을 시키시겠습니까efj
# 형식이 잘못되었습니다
#
#
#
# 1. 파스타 1,0000원
# 2. 라떼  5,000원
#
#
#
#
# 메뉴를 선정하세요: >>>3rwkf
# 형식이 잘못되었습니다
#
#
#
# 1. 파스타 1,0000원
# 2. 라떼  5,000원
