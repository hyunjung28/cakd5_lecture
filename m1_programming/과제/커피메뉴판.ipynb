# %%
menu='''




-----메뉴-------
1. 아메리카노 2000원
2. 라떼 3000원
3. 에이드 3000원

sirup 시럽 500원

'''

print('어서오세요. 1초 내맘대로 커피 입니다..' + ' \n')
print("="*40)
print(menu)
print("="*40)

order = input('메뉴를 선택해주세요. 1,2,3, >> ')
sirup = input('시럽을 추가하시겠습니까? y/n  ')

price1=2000
price2=3000
price3=3000
sirup = 500

if order =='1':
    while 1 : 
        sirup= input("시럽을 추가하시겠습니까? y/n  ")
        if sirup=="y":
                 price1 +=  500
                 print(f'총 금액은 {price1}원 입니다')
        elif sirup=="n":
                 print(f'총 금액은 {price1}원 입니다')
       
        else:
            break
        
if order =='2':
    while 1 : 
        sirup= input("시럽을 추가하시겠습니까? y/n  ")
        if sirup=="y":
                 price2 +=  500
                 print(f'총 금액은 {price2}원 입니다')
        elif sirup=="n":
                 print(f'총 금액은 {price2}원 입니다') 
        else: 
            print("처음으로 돌아갑니다")
            
if order =='3':
    while 1 : 
        sirup= input("시럽을 추가하시겠습니까? y/n  ")
        if sirup=="y":
                 price3 +=  500
                 print(f'총 금액은 {price3}원 입니다')
        elif sirup=="n":
                 print(f'총 금액은 {price3}원 입니다') 
        else: 
            print("처음으로 돌아갑니다")
# Out:
# 어서오세요. 1초 내맘대로 커피 입니다..
#
# ...
#
#
#
#
#
# -----메뉴-------
# 1. 아메리카노 2000원
# 2. 라떼 3000원
# 3. 에이드 3000원
#
# sirup 시럽 500원
#
#
# ...
# 메뉴를 선택해주세요. 1,2,3, >> 1
# 시럽을 추가하시겠습니까? y/n  y
# 시럽을 추가하시겠습니까? y/n  y
# 총 금액은 2500원 입니다
# 시럽을 추가하시겠습니까? y/n  n
# 총 금액은 2500원 입니다
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1180/2437374033.py in <module>
#      28 if order =='1':
#      29     while 1 :
# ---> 30         sirup= input("시럽을 추가하시겠습니까? y/n  ")
#      31         if sirup=="y":
#      32                  price1 +=  500
#
# ~\Anaconda3\envs\cakd5\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1008             self._parent_ident["shell"],
#    1009             self.get_parent("shell"),
# -> 1010             password=False,
#    1011         )
#    1012
#
# ...

# %%
menu='''




-----메뉴-------
1. 아메리카노 2000원
2. 라떼 3000원
3. 에이드 3000원

sirup 시럽 500원

'''

print('어서오세요. 1초 내맘대로 커피 입니다..' + ' \n')
print("="*40)
print(menu)
print("="*40)

order = input('메뉴를 선택해주세요. 1,2,3, >> ')
sirup = input('시럽을 추가하시겠습니까? y/n  ')

price=0
sirup = 500

if order =='1':
    price=2000
    print(f'총 금액은 {price}원 입니다')
       
      
        
elif order =='2':
    price=3000
    print(f'총 금액은 {price}원 입니다')
                 
        
            
else:
    price=3000
    print(f'총 금액은 {price}원 입니다')

    
if sirup =='y':
    price += 500
elif sirup == 'n':
    price = price
else: 
    print('잘못 입력하였습니다')
# Out:
# 어서오세요. 1초 내맘대로 커피 입니다..
#
# ...
#
#
#
#
#
# -----메뉴-------
# 1. 아메리카노 2000원
# 2. 라떼 3000원
# 3. 에이드 3000원
#
# sirup 시럽 500원
#
#
# ...
# 메뉴를 선택해주세요. 1,2,3, >> 1
# 시럽을 추가하시겠습니까? y/n  y
# 총 금액은 2000원 입니다
# 잘못 입력하였습니다

# %%
menu1='''




-----메뉴-------

1. 파스타 10000원
2. 라떼 5000원

'''

menu2='''




-----메뉴-------
1. 베지전용 파스타 10000원
2. 베지라떼 5000원


'''


print('어서오세요.식당 입니다.' + ' \n')
print("="*40)
print("="*40)

vegan_menu1 = "vegan pasta"
vegan_menu2 = "vegan latte"




veg_pas = 10000
veg_la = 5000
pas =10000
la = 5000



choice = input('일반과 비건 중 선택해주세요. 일반:1,비건:2>> ')



if choice =='1':
    print(menu1)
    
    order= input("메뉴를 선정하세요:")
    if order == '1':
        price = pas
        print(f"파스타의 가격은 {pas}입니다")
        add = input('라떼를 추가 주문 하시겠습니까?>> y/n ')
        if add == 'y':
                price = pas+la
                print(f'총 가격은  {price}입니다.')
        else:
            print(f'총가격은 {pas}입니다')
                
                
                
                
    elif order =='2':
        price = la
        print(f"라떼의 가격은  {la}입니다")
    else:
        print('잘못 입력하였습니다')
       
      
else:
    print(menu2)

    order= input("메뉴를 선정하세요:")
    if order =='1':
        price=veg_pas
        print(f'총 금액은 {veg_pas}원 입니다')
        v_add = input('라떼를 추가 주문 하시겠습니까?>> y/n ')
        if v_add == 'y':
                price2 = veg_pas+veg_la
                print(f'총 가격은  {price2}입니다.')
        else:
            print(f'총가격은 {veg_pas}입니다')       
        
        
        
        
        
    elif order =='2':
        price=5000
        print(f'총 금액은 {price}원 입니다')
    else: 
        print('잘못 입력하였습니다')
# Out:
# 어서오세요.식당 입니다.
#
# ...
# 일반과 비건 중 선택해주세요. 일반:1,비건:2>> 2
#
#
#
#
#
# -----메뉴-------
# 1. 베지전용 파스타 10000원
# 2. 베지라떼 5000원
#
#
#
# 메뉴를 선정하세요:1
# 총 금액은 10000원 입니다
# 라떼를 추가 주문 하시겠습니까?>> y/n y
# 총 가격은  15000입니다.
