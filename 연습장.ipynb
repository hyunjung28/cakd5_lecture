# %%
menu= '''

======================================================

'어세오세요 식당'입니다. 보고 싶은 메뉴판을 선택하세요

1. 일반 메뉴판

2. 베지 메뉴판


======================================================
'''



menu1 = '''


1. 파스타 1,0000원
2. 라떼  5,000원



'''


menu2 = '''

<당신의 채식 유형을 선택해주세요>


1. 락토오보 채식 (채식, 우유, 유제품, 달걀)

2. 페스코채식 (채식,우유,달걀, 어류)

3. 락토 채식(채식,우유, 유제품)

4. 플렉시테리안(채식,육식)


'''


menu3 = '''


1.아이스크림 3000원
2.밀크티 4000원



'''
pasta =10000
latte = 5000
ice= 3000
milk = 4000

price_sum=0


print(menu)

want = int(input(" 메뉴판을 선택하세요 : >>>  "))


    
if want ==1:
    
    
    
    while 1:
        print(menu1)
        order= input("메뉴를 선정하세요: >>>")
        if order == '1':
            x = int(input("몇 인분을 시키시겠습니까"))
            price_sum += (pasta*x)
            print(f"주문하신 음식의 가격은 {price_sum}입니다")

        elif order =='2':
            x_2 = int(input("몇 인분을 시키시겠습니까"))
            price_sum += (latte*x_2)
            
        add = input('추가 주문 하시겠습니까?>> y/n ')   
        if add == 'y':
            continue
        elif add=='n':
            print(f'주문하신 음식의 가격은 {price_sum}입니다. 즐거운 식사 되세요')
            print("★다음 번에 또 방문해주세요 ★")
            break
            
        else:
                print('입력 오류 입니다. y/n로만 답해주세요')
            
class MyClass :
    var = '안녕하세요' #클래스 멤버(or 변수)
    def SayHello(self): #클래스 메소드
        return self.var 
obj = MyClass()
print(obj.var)
print(obj.SayHello())            
            
class Ment:
    var = '다음번에 또 방문해주세요'
    def mention(self):
        return self.var
a = Ment()
print(a.var)
# Out:
# ...
#
# '어세오세요 식당'입니다. 보고 싶은 메뉴판을 선택하세요
#
# 1. 일반 메뉴판
#
# 2. 베지 메뉴판
#
#
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12060/3312924784.py in <module>
#      62 print(menu)
#      63
# ---> 64 want = int(input(" 메뉴판을 선택하세요 : >>>  "))
#      65
#      66
#
# ~\Anaconda3\envs\cakd5\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1008             self._parent_ident["shell"],
#    1009             self.get_parent("shell"),
# -> 1010             password=False,
#    1011         )
#    1012
#
# ~\Anaconda3\envs\cakd5\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
#    1050                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1051                 raise KeyboardInterrupt("Interrupted by user") from None
# ...

# %%
class Ment:
    var = '다음번에 또 방문해주세요'
    def mention(self):
        return self.var
a = Ment()
print(a.var)
# Out:
# 다음번에 또 방문해주세요

# %%
menu= '''

======================================================

'어세오세요 식당'입니다. 보고 싶은 메뉴판을 선택하세요.

1. 일반 메뉴판

2. 베지 메뉴판


======================================================
'''



menu1 = '''


1. 파스타 1,0000원
2. 라떼  5,000원



'''


menu3 = '''

<당신의 채식 유형을 선택해주세요>


1. 락토오보 채식 (채식, 우유, 유제품, 달걀)

2. 페스코채식 (채식,우유,달걀, 어류)

3. 락토 채식(채식,우유, 유제품)

4. 플렉시테리안(채식,육식)


'''



menu2 = '''


1. 아이스크림 3000원
2. 밀크티 4000원


'''







class Menu:
    def menu (self,num):
        price_sum=0
        while 1:
            if num ==2:
                print(menu3)
            
            x = int(input('당신의 채식 유형을 선택하세요 >> '))
            if x == 1:
                print(menu2)
            else: 
                print(menu2)
            order = int(input("메뉴를 선택하세요 : >>"))
            if order ==1:
                y = int(input("몇 인분을 시키시겠습니까"))
                price_sum += (food[num-1][0]*y)
                print(f"주문하신 음식의 가격은 {price_sum}입니다")

            elif order ==2:
                y_2 = int(input("몇 인분을 시키시겠습니까"))
                price_sum += (food[num-1][1]*y_2)
            
            add = input('추가 주문 하시겠습니까?>> y/n ')
            if add == 'y':

                continue
                
                print(f'주문하신 음식의 총 가격은  {price_sum}입니다.즐거운 식사 되세요')
            elif add =='n':

                print(f'파스타의 가격은 {price_sum}입니다. 즐거운 식사 되세요')
                print("★다음 번에 또 방문해주세요 ★")
                break
            else:
                print('입력 오류 입니다. y/n로만 답해주세요')


            
            
            
            
            
#메인코드         
food = [(10000,5000),(3000,40000)]
price_sum=0

print(menu)
a= Menu()

want = int(input(" 메뉴판을 선택하세요 : >>>  "))
a.menu(want)
# Out:
# ...
#
# '어세오세요 식당'입니다. 보고 싶은 메뉴판을 선택하세요.
#
# 1. 일반 메뉴판
#
# 2. 베지 메뉴판
#
#
# ...
#
#  메뉴판을 선택하세요 : >>>  2
#
#
# <당신의 채식 유형을 선택해주세요>
#
#
# 1. 락토오보 채식 (채식, 우유, 유제품, 달걀)
#
# 2. 페스코채식 (채식,우유,달걀, 어류)
#
# 3. 락토 채식(채식,우유, 유제품)
#
# 4. 플렉시테리안(채식,육식)
#
#
#
# 당신의 채식 유형을 선택하세요 >> 1
#
#
#
# 1. 아이스크림 3000원
# 2. 밀크티 4000원
#
#
#
# 메뉴를 선택하세요 : >>1
# 몇 인분을 시키시겠습니까1
# 주문하신 음식의 가격은 3000입니다
# 추가 주문 하시겠습니까?>> y/n ㅛ
# 입력 오류 입니다. y/n로만 답해주세요
#
#
# <당신의 채식 유형을 선택해주세요>
#
#
# 1. 락토오보 채식 (채식, 우유, 유제품, 달걀)
#
# 2. 페스코채식 (채식,우유,달걀, 어류)
#
# 3. 락토 채식(채식,우유, 유제품)
#
# 4. 플렉시테리안(채식,육식)
#
#
#
# 당신의 채식 유형을 선택하세요 >> ㅜ
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12060/2996496132.py in <module>
#     109
#     110 want = int(input(" 메뉴판을 선택하세요 : >>>  "))
# --> 111 a.menu(want)
#     112
#
# ~\AppData\Local\Temp/ipykernel_12060/2996496132.py in menu(self, num)
# ...

# %%
try:
    int('a')
except ValueError:
    print("e")
# Out:
# e

# %%
menu= '''

======================================================

'어세오세요 식당'입니다. 보고 싶은 메뉴판을 선택하세요

1. 일반 메뉴판

2. 베지 메뉴판


======================================================
'''



menu1 = '''


1. 파스타 1,0000원
2. 라떼  5,000원



'''


menu2 = '''

<당신의 채식 유형을 선택해주세요>


1. 락토오보 채식 (채식, 우유, 유제품, 달걀)

2. 페스코채식 (채식,우유,달걀, 어류)

3. 락토 채식(채식,우유, 유제품)

4. 플렉시테리안(채식,육식)


'''


menu3 = '''


1.아이스크림 3000원
2.밀크티 4000원



'''
pasta =10000
latte = 5000
ice= 3000
milk = 4000

price_sum=0


print(menu)

want = int(input(" 메뉴판을 선택하세요 : >>>  "))

class 
    
if want ==1:
    
    
    
    while 1:
        print(menu1)
        order= input("메뉴를 선정하세요: >>>")
        if order == '1':
            x = int(input("몇 인분을 시키시겠습니까"))
            price_sum += (pasta*x)
            print(f"주문하신 음식의 가격은 {price_sum}입니다")

        elif order =='2':
            x_2 = int(input("몇 인분을 시키시겠습니까"))
            price_sum += (latte*x_2)
            
        add = input('추가 주문 하시겠습니까?>> y/n ')   
        if add == 'y':
            continue
        elif add=='n':
            print(f'주문하신 음식의 가격은 {price_sum}입니다. 즐거운 식사 되세요')
            print("★다음 번에 또 방문해주세요 ★")
            break
            
        else:
                print('입력 오류 입니다. y/n로만 답해주세요')
