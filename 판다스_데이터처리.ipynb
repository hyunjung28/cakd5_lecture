# %%
import pandas as pd
file_data =pd.read_csv('./dataset/file_data.csv')
file_data['가격']=[5000,5000,4000,6000,3000]
file_data
# Out:
#     차림표    가격
# 0    냉면  5000
# 1   콩국수  5000
# 2  잔치국수  4000
# 3   수제비  6000
# 4    우동  3000

# %%
df1 = file_data.copy()
df2 = pd.DataFrame({
    '차림표' : ['자장면','탕수육','돈까스','라면','김밥'],
    '가격':[7000,8000,7000,6000,5000]
})
df2
# Out:
#    차림표    가격
# 0  자장면  7000
# 1  탕수육  8000
# 2  돈까스  7000
# 3   라면  6000
# 4   김밥  5000

# %%
#병합-세로병함
pd.concat([df1,df2])
x=pd.concat([df1,df2])
x
# Out:
#     차림표    가격
# 0    냉면  5000
# 1   콩국수  5000
# 2  잔치국수  4000
# 3   수제비  6000
# 4    우동  3000
# 0   자장면  7000
# 1   탕수육  8000
# 2   돈까스  7000
# 3    라면  6000
# 4    김밥  5000

# %%
#인덱스 재정렬
ndf=x.reset_index()
ndf.drop('index',axis=1) #inplace=True주면 원본도 수정됨
# Out:
#     차림표    가격
# 0    냉면  5000
# 1   콩국수  5000
# 2  잔치국수  4000
# 3   수제비  6000
# 4    우동  3000
# 5   자장면  7000
# 6   탕수육  8000
# 7   돈까스  7000
# 8    라면  6000
# 9    김밥  5000

# %%
ndf.index=np.arange(1,11)
ndf
# Out:
#     index   차림표    가격
# 1       0    냉면  5000
# 2       1   콩국수  5000
# 3       2  잔치국수  4000
# 4       3   수제비  6000
# 5       4    우동  3000
# 6       0   자장면  7000
# 7       1   탕수육  8000
# 8       2   돈까스  7000
# 9       3    라면  6000
# 10      4    김밥  5000

# %%
#인덱스 지정한 데로 설정: reindex
new_index=np.arange(0,11)
ndf2 = ndf1.reindex(new_index,fill_value=0)
ndf2 #fill_value 에 뭐 넣어줄 ㅅ 있음
# Out:
#     index   차림표    가격
# 0       0     0     0
# 1       0    냉면  5000
# 2       1   콩국수  5000
# 3       2  잔치국수  4000
# 4       3   수제비  6000
# 5       4    우동  3000
# 6       0   자장면  7000
# 7       1   탕수육  8000
# 8       2   돈까스  7000
# 9       3    라면  6000
# 10      4    김밥  5000

# %%
new_index=np.arange(1,16)
ndf2 = ndf1.reindex(new_index,fill_value=0)
ndf2
# Out:
#     index   차림표    가격
# 1       0    냉면  5000
# 2       1   콩국수  5000
# 3       2  잔치국수  4000
# 4       3   수제비  6000
# 5       4    우동  3000
# 6       0   자장면  7000
# 7       1   탕수육  8000
# 8       2   돈까스  7000
# 9       3    라면  6000
# 10      4    김밥  5000
# 11      0     0     0
# 12      0     0     0
# 13      0     0     0
# 14      0     0     0
# 15      0     0     0

# %%
#내림차순 ㅓㅇ렬
ndf1 =ndf.sort_index(ascending=False)
ndf1
# Out:
#     index   차림표    가격
# 10      4    김밥  5000
# 9       3    라면  6000
# 8       2   돈까스  7000
# 7       1   탕수육  8000
# 6       0   자장면  7000
# 5       4    우동  3000
# 4       3   수제비  6000
# 3       2  잔치국수  4000
# 2       1   콩국수  5000
# 1       0    냉면  5000

# %%
ndf2=ndf1.sort_index(ascending=True)
ndf2
# Out:
#     index   차림표    가격
# 1       0    냉면  5000
# 2       1   콩국수  5000
# 3       2  잔치국수  4000
# 4       3   수제비  6000
# 5       4    우동  3000
# 6       0   자장면  7000
# 7       1   탕수육  8000
# 8       2   돈까스  7000
# 9       3    라면  6000
# 10      4    김밥  5000

# %%
ndf3 =ndf2.sort_values(by='가격')
print(ndf3)

#차림표, 가격 두개를 기준으로 내림차순 하고 싶다-> 리스트로 하면됨
ndf4 = ndf3.sort_values(by=['차림표','가격'])
ndf4

ndf5 =ndf4.reset_index()
ndf5
# Out:
#     index   차림표    가격
# 5       4    우동  3000
# 3       2  잔치국수  4000
# 1       0    냉면  5000
# 2       1   콩국수  5000
# 10      4    김밥  5000
# 4       3   수제비  6000
# 9       3    라면  6000
# 6       0   자장면  7000
# 8       2   돈까스  7000
# 7       1   탕수육  8000
#    level_0  index   차림표    가격
# 0       10      4    김밥  5000
# 1        1      0    냉면  5000
# 2        8      2   돈까스  7000
# 3        9      3    라면  6000
# 4        4      3   수제비  6000
# 5        5      4    우동  3000
# 6        6      0   자장면  7000
# 7        3      2  잔치국수  4000
# 8        2      1   콩국수  5000
# 9        7      1   탕수육  8000

# %%
#병합-가로방향
dfc2 = pd.concat([df1,df2],axis=1)
dfc2
# Out:
#     차림표    가격  차림표    가격
# 0    냉면  5000  자장면  7000
# 1   콩국수  5000  탕수육  8000
# 2  잔치국수  4000  돈까스  7000
# 3   수제비  6000   라면  6000
# 4    우동  3000   김밥  5000

# %%
import warnings
warnings.filterwarnings('ignore')

new_column = ['메뉴1','가격1','메뉴2','가격2']
dfc2.columns= new_column
dfc2
# Out:
#     메뉴1   가격1  메뉴2   가격2
# 0    냉면  5000  자장면  7000
# 1   콩국수  5000  탕수육  8000
# 2  잔치국수  4000  돈까스  7000
# 3   수제비  6000   라면  6000
# 4    우동  3000   김밥  5000

# %% [raw]
# #시리즈 -> 데이터프레임
# df= pd.concat ([sr1,sr2],axis=1)

# %%
sr1 = dfc2['메뉴1']
sr2 = dfc2 ['가격2']
print(sr1)
print(sr2)
# Out:
# 0      냉면
# 1     콩국수
# 2    잔치국수
# 3     수제비
# 4      우동
# Name: 메뉴1, dtype: object
# 0    7000
# 1    8000
# 2    7000
# 3    6000
# 4    5000
# Name: 가격2, dtype: int64

# %%
dfc3 = dfc2.copy()
dfc3['메뉴1']=['a','b','c','d','e']
dfc3
# Out:
#   메뉴1   가격1  메뉴2   가격2
# 0   a  5000  자장면  7000
# 1   b  5000  탕수육  8000
# 2   c  4000  돈까스  7000
# 3   d  6000   라면  6000
# 4   e  3000   김밥  5000

# %%
#삭제, inplace=True는 원본에 반영함을 의미 , 2개 이상일 땐 [] 리스트로 괄호묶음
dfc3.drop(['가격1','가격2'],axis=1,inplace=True)
dfc3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9292/3913395413.py in <module>
#       1 #삭제, inplace=True는 원본에 반영함을 의미 , 2개 이상일 땐 [] 리스트로 괄호묶음
# ----> 2 dfc3.drop(['가격1','가격2'],axis=1,inplace=True)
#       3 dfc3
#
# ~\Anaconda3\envs\cakd5\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ~\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['가격1' '가격2'] not found in axis"

# %%
# 행 삭제
dfc3.drop([0],axis=0) #이미지워졌어 
dfc3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9292/3304924544.py in <module>
#       1 # 행 삭제
# ----> 2 dfc3.drop([0],axis=0)
#       3 dfc3
#
# ~\Anaconda3\envs\cakd5\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ~\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: '[0] not found in axis'

# %%
dfc3 = dfc2.copy()
dfc3
# Out:
#     메뉴1   가격1  메뉴2   가격2
# 0    냉면  5000  자장면  7000
# 1   콩국수  5000  탕수육  8000
# 2  잔치국수  4000  돈까스  7000
# 3   수제비  6000   라면  6000
# 4    우동  3000   김밥  5000

# %%
#행, 열 모두에 조건 지정
p = dfc3.loc[dfc3['가격1']>5000]
p
q = dfc3.loc[dfc3[0]:'자장면']
q
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9292/1345035578.py in <module>
#       1 #행, 열 모두에 조건 지정
# ----> 2 p = dfc3.loc[dfc3['가격1']>5000]
#       3 p
#       4 q = dfc3.loc[dfc3[0]:'자장면']
#       5 q
#
# ~\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\arraylike.py in __gt__(self, other)
#      46     @unpack_zerodim_and_defer("__gt__")
#      47     def __gt__(self, other):
# ---> 48         return self._cmp_method(other, operator.gt)
#      49
#      50     @unpack_zerodim_and_defer("__ge__")
#
# ~\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5500
#    5501         with np.errstate(all="ignore"):
# -> 5502             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5503
#    5504         return self._construct_result(res_values, name=res_name)
#
# ~\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     282
#     283     elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 284         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285
#     286     else:
#
# ~\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      71         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      72     else:
# ---> 73         result = libops.scalar_compare(x.ravel(), y, op)
#      74     return result.reshape(x.shape)
#      75
#
# ~\Anaconda3\envs\cakd5\lib\site-packages\pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
#행추가
dfc3.loc[5]=['라면','4000','만두','3000']
dfc3
# Out:
#     메뉴1   가격1  메뉴2   가격2
# 0    냉면  5000  자장면  7000
# 1   콩국수  5000  탕수육  8000
# 2  잔치국수  4000  돈까스  7000
# 3   수제비  6000   라면  6000
# 4    우동  3000   김밥  5000
# 5    라면  4000   만두  3000

# %%
#열추가
dfc3['메뉴3']=dfc3.메뉴1
dfc3
# Out:
#     메뉴1   가격1  메뉴2   가격2   메뉴3
# 0    냉면  5000  자장면  7000    냉면
# 1   콩국수  5000  탕수육  8000   콩국수
# 2  잔치국수  4000  돈까스  7000  잔치국수
# 3   수제비  6000   라면  6000   수제비
# 4    우동  3000   김밥  5000    우동
# 5    라면  4000   만두  3000    라면

# %%
#[과제]인덱싱을 이용하여 특정 컬럼, 특정 행, 특정 값을 추출
dfc3['메뉴1'][3:]
# Out:
# 3    수제비
# 4     우동
# Name: 메뉴1, dtype: object

# %%
#조건(하나 또는 복수)에 맞는 데이터 추출- 불린 인덱싱

dfc3.loc[dfc3['가격1']>5000]
dfc3.loc[dfc3['가격2']<8000,['메뉴1','가격1']]#메뉴1과 가격1 에서 선택하는거
# Out:
#     메뉴1   가격1
# 0    냉면  5000
# 2  잔치국수  4000
# 3   수제비  6000
# 4    우동  3000

# %%
#전체행을 2행 간격으로 선택, 역순으로 인덱싱
dfc3[::-1]
dfc3[::2]
# Out:
#     메뉴1   가격1  메뉴2   가격2
# 0    냉면  5000  자장면  7000
# 2  잔치국수  4000  돈까스  7000
# 4    우동  3000   김밥  5000

# %%
import pandas as pd
import numpy as np
columns = ['kor','eng','art','math','gym','sci']
index = ['jim','sam','tom','tim','bob']
data = np.random.randint(70,100,size=(5,6))
df = pd.DataFrame(data,index,columns=columns)
df
# Out:
#      kor  eng  art  math  gym  sci
# jim   72   79   82    75   90   94
# sam   72   94   70    97   92   80
# tom   84   87   77    77   72   87
# tim   97   96   97    94   81   72
# bob   79   94   86    99   76   99

# %% [markdown]
# [과제] iloc, loc를 이용해서 아래 요구사항들을 출력하세요
#
# - df의 kor열을 series와 dataframe을 각각 출력
# - df에서 sam의 math 점수를 출력(2가지 방법)
# - df에서 tom의 eng와 sci 점수를 출력(2가지 방법)
# - df에서 jim, tim의 eng, gym 점수를 출력
# - df에서 jim, sam의 art,math,gym 점수를 출력
# [과제] iloc, loc를 이용해서 아래 요구사항들을 수행하세요
#
# - df에서 sam의 math 점수를 100으로 변경
# - df에서 tom의 eng와 math 점수를 100으로 변경
# - df에서 jim, tim의 kor, gym 점수를 null값으로 변경
# - df에서 math와 gym 점수를 바꾸어 출력(미완)

# %%
#df에서 sam의 math 점수를 100으로 변경
df.iloc[1,3]='100'
df
# Out:
#      kor  eng  art math  gym  sci
# jim   72   79   82   75   90   94
# sam   72   94   70  100   92   80
# tom   84   87   77   77   72   87
# tim   97   96   97   94   81   72
# bob   79   94   86   99   76   99

# %%
#df에서 tom의 eng와 math 점수를 100으로 변경
df.loc[['tom'],['eng','math']]=100
df
# Out:
#      kor  eng  art math  gym  sci
# jim   72   79   82   75   90   94
# sam   72   94   70  100   92   80
# tom   84  100   77  100   72   87
# tim   97   96   97   94   81   72
# bob   79   94   86   99   76   99

# %%
#df에서 jim, tim의 kor, gym 점수를 null값으로 변경
df.loc[['jim','tim'],['kor','gym']]=np.nan
df
# Out:
#       kor  eng  art math   gym  sci
# jim   NaN   79   82   75   NaN   94
# sam  72.0   94   70  100  92.0   80
# tom  84.0  100   77  100  72.0   87
# tim   NaN   96   97   94   NaN   72
# bob  79.0   94   86   99  76.0   99

# %%
#df에서 math와 gym 점수를 바꾸어 출력
df['math'].replace([75,100,100,94,99],[0,92,72,0,76])
df
# Out:
#       kor  eng art math   gym sci
# jim   NaN   79  82   75   NaN  94
# sam  72.0   94  70  100  92.0  80
# tom  84.0  100  77  100  72.0  87
# tim   NaN   96  97   94   NaN  72
# bob  79.0   94  86   99  76.0  99

# %%
#df에서 jim, sam의 art,math,gym 점수를 출력 
print(df.loc[['jim','sam'],['art','math','gym']])
print(df.iloc[0:2,2:5])
# Out:
#      art  math  gym
# jim   82    75   90
# sam   70    97   92
#      art  math  gym
# jim   82    75   90
# sam   70    97   92

# %%
#df에서 jim, tim의 eng, gym 점수를 출력
print(df.iloc[[0,3],[1,4]])
# Out:
#      eng  gym
# jim   79   90
# tim   96   81

# %%
#df의 kor열을 series와 dataframe을 각각 출력
x = df.iloc[:,0]

sr=pd.Series(x)
print(sr,'\n')

kor = pd.DataFrame(x)
print(kor,'\n')
# Out:
# jim    72
# sam    72
# tom    84
# tim    97
# bob    79
# Name: kor, dtype: int32
#
#      kor
# jim   72
# sam   72
# tom   84
# tim   97
# bob   79

# %%
#df에서 sam의 math 점수를 출력(2가지 방법)
print(df.loc['sam','math'])
print(df.iloc[1,3])
# Out:
# 97
# 97

# %%
#df에서 tom의 eng와 sci 점수를 출력(2가지 방법)
print(df.loc[['tom'],['eng','sci']])

print(df.iloc[[2],[1,5]])
# Out:
#      eng  sci
# tom   87   87
#      eng  sci
# tom   87   87

# %%
# [과제] 데이터 추출(인덱싱, 조건), 변경, 삭제, 정렬, 칼럼 병합(sibsp + parch =s 등을 수행하여 
#데이터에서 인사이트 찾기

# %%
import seaborn as sns
df = sns.load_dataset('titanic')
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
df.groupby(['sex','survived'])['survived'].count()
sns.barplot(x='sex',y='survived',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='survived'>

# %%
sns.barplot(x='class',y='survived',hue='sex',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='survived'>

# %%
df.iloc[:,1]
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64
